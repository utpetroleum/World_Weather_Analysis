# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 611

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | caxito
# Processing Record 5 of Set 1 | yuncheng
# Processing Record 6 of Set 1 | lagoa
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | chumikan
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | fortuna
# Processing Record 12 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 1 | yerbogachen
# Processing Record 14 of Set 1 | zaysan
# Processing Record 15 of Set 1 | syamzha
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 1 | gold coast
# Processing Record 21 of Set 1 | mitsamiouli
# Processing Record 22 of Set 1 | rypefjord
# Processing Record 23 of Set 1 | college
# Processing Record 24 of Set 1 | melilla
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | umm lajj
# Processing Record 27 of Set 1 | seoul
# Processing Record 28 of Set 1 | ugoofaaru
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | narrabri
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | baykit
# Processing Record 35 of Set 1 | thompson
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | avera
# Processing Record 43 of Set 1 | bengkulu
# Processing Record 44 of Set 1 | fernley
# Processing Record 45 of Set 1 | komsomolskiy
# Processing Record 46 of Set 1 | saint george
# Processing Record 47 of Set 1 | buraydah
# Processing Record 48 of Set 1 | dukat
# Processing Record 49 of Set 1 | marystown
# Processing Record 50 of Set 1 | guararema
# Processing Record 1 of Set 2 | inhambane
# Processing Record 2 of Set 2 | ishigaki
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | kjollefjord
# Processing Record 6 of Set 2 | olafsvik
# Processing Record 7 of Set 2 | port lincoln
# Processing Record 8 of Set 2 | artyshta
# Processing Record 9 of Set 2 | richards bay
# Processing Record 10 of Set 2 | albufeira
# Processing Record 11 of Set 2 | huilong
# Processing Record 12 of Set 2 | hounde
# Processing Record 13 of Set 2 | guerrero negro
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | hurghada
# Processing Record 16 of Set 2 | arsk
# Processing Record 17 of Set 2 | abaza
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | praia da vitoria
# Processing Record 20 of Set 2 | lashio
# Processing Record 21 of Set 2 | longyearbyen
# Processing Record 22 of Set 2 | san patricio
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | northam
# Processing Record 29 of Set 2 | quatre cocos
# Processing Record 30 of Set 2 | cuamba
# Processing Record 31 of Set 2 | yar-sale
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | gat
# Processing Record 34 of Set 2 | sao filipe
# Processing Record 35 of Set 2 | ankazobe
# Processing Record 36 of Set 2 | nanortalik
# Processing Record 37 of Set 2 | labuhan
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | awbari
# Processing Record 40 of Set 2 | hauterive
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | hoa binh
# Processing Record 43 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 2 | caloundra
# Processing Record 45 of Set 2 | la macarena
# Processing Record 46 of Set 2 | samarai
# Processing Record 47 of Set 2 | macusani
# Processing Record 48 of Set 2 | clyde river
# Processing Record 49 of Set 2 | tual
# Processing Record 50 of Set 2 | joshimath
# Processing Record 1 of Set 3 | ponta do sol
# Processing Record 2 of Set 3 | bathsheba
# Processing Record 3 of Set 3 | thunder bay
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 3 | kununurra
# Processing Record 7 of Set 3 | coos bay
# Processing Record 8 of Set 3 | ostrovnoy
# Processing Record 9 of Set 3 | namibe
# Processing Record 10 of Set 3 | norman wells
# Processing Record 11 of Set 3 | airai
# Processing Record 12 of Set 3 | bluff
# Processing Record 13 of Set 3 | dauphin
# Processing Record 14 of Set 3 | maniitsoq
# Processing Record 15 of Set 3 | georgetown
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | muros
# Processing Record 18 of Set 3 | vardo
# Processing Record 19 of Set 3 | severnyy
# Processing Record 20 of Set 3 | cradock
# Processing Record 21 of Set 3 | biltine
# Processing Record 22 of Set 3 | butaritari
# Processing Record 23 of Set 3 | mount isa
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | sisimiut
# Processing Record 26 of Set 3 | esmeraldas
# Processing Record 27 of Set 3 | hermanus
# Processing Record 28 of Set 3 | la ronge
# Processing Record 29 of Set 3 | kyra
# Processing Record 30 of Set 3 | bireun
# Processing Record 31 of Set 3 | tuatapere
# Processing Record 32 of Set 3 | miraflores
# Processing Record 33 of Set 3 | yaan
# Processing Record 34 of Set 3 | huarmey
# Processing Record 35 of Set 3 | fairbanks
# Processing Record 36 of Set 3 | nakonde
# Processing Record 37 of Set 3 | ayagoz
# Processing Record 38 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 3 | saldanha
# Processing Record 40 of Set 3 | coihaique
# Processing Record 41 of Set 3 | puerto ayora
# Processing Record 42 of Set 3 | meiganga
# Processing Record 43 of Set 3 | victoria
# Processing Record 44 of Set 3 | marawi
# Processing Record 45 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 3 | imeni poliny osipenko
# Processing Record 47 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 3 | clinton
# Processing Record 49 of Set 3 | mataura
# Processing Record 50 of Set 3 | kasempa
# Processing Record 1 of Set 4 | nikolskoye
# Processing Record 2 of Set 4 | barkot
# Processing Record 3 of Set 4 | geraldton
# Processing Record 4 of Set 4 | bredasdorp
# Processing Record 5 of Set 4 | machinga
# Processing Record 6 of Set 4 | waipawa
# Processing Record 7 of Set 4 | eston
# Processing Record 8 of Set 4 | faanui
# Processing Record 9 of Set 4 | dekar
# Processing Record 10 of Set 4 | bambous virieux
# Processing Record 11 of Set 4 | lagos
# Processing Record 12 of Set 4 | shimoda
# Processing Record 13 of Set 4 | altagracia de orituco
# Processing Record 14 of Set 4 | bada
# Processing Record 15 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 4 | padang
# Processing Record 17 of Set 4 | kodiak
# Processing Record 18 of Set 4 | dalbandin
# Processing Record 19 of Set 4 | lebu
# Processing Record 20 of Set 4 | itanagar
# Processing Record 21 of Set 4 | alto baudo
# City not found. Skipping...
# Processing Record 22 of Set 4 | hofn
# Processing Record 23 of Set 4 | mushie
# Processing Record 24 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 4 | necochea
# Processing Record 26 of Set 4 | vao
# Processing Record 27 of Set 4 | wembley
# Processing Record 28 of Set 4 | columbus
# Processing Record 29 of Set 4 | isangel
# Processing Record 30 of Set 4 | kalmunai
# Processing Record 31 of Set 4 | jinchang
# Processing Record 32 of Set 4 | caravelas
# Processing Record 33 of Set 4 | yumen
# Processing Record 34 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 4 | chokurdakh
# Processing Record 36 of Set 4 | valparaiso
# Processing Record 37 of Set 4 | tuensang
# Processing Record 38 of Set 4 | new norfolk
# Processing Record 39 of Set 4 | loralai
# Processing Record 40 of Set 4 | avarua
# Processing Record 41 of Set 4 | chikoy
# City not found. Skipping...
# Processing Record 42 of Set 4 | qinhuangdao
# Processing Record 43 of Set 4 | kungurtug
# Processing Record 44 of Set 4 | itarema
# Processing Record 45 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 4 | conde
# Processing Record 48 of Set 4 | narsaq
# Processing Record 49 of Set 4 | bucerias
# Processing Record 50 of Set 4 | ribeira brava
# Processing Record 1 of Set 5 | vershino-shakhtaminskiy
# Processing Record 2 of Set 5 | poum
# Processing Record 3 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 5 | carutapera
# Processing Record 5 of Set 5 | juneau
# Processing Record 6 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 5 | kutum
# Processing Record 8 of Set 5 | budogoshch
# Processing Record 9 of Set 5 | east london
# Processing Record 10 of Set 5 | beringovskiy
# Processing Record 11 of Set 5 | jizan
# Processing Record 12 of Set 5 | sioux lookout
# Processing Record 13 of Set 5 | bella union
# Processing Record 14 of Set 5 | kamina
# Processing Record 15 of Set 5 | amli
# Processing Record 16 of Set 5 | dikson
# Processing Record 17 of Set 5 | foz
# Processing Record 18 of Set 5 | sayyan
# Processing Record 19 of Set 5 | mahebourg
# Processing Record 20 of Set 5 | tiksi
# Processing Record 21 of Set 5 | fabiansebestyen
# Processing Record 22 of Set 5 | kolhapur
# Processing Record 23 of Set 5 | bria
# Processing Record 24 of Set 5 | namtsy
# Processing Record 25 of Set 5 | vila
# Processing Record 26 of Set 5 | vanavara
# Processing Record 27 of Set 5 | lagunas
# Processing Record 28 of Set 5 | sagua la grande
# Processing Record 29 of Set 5 | brownsville
# Processing Record 30 of Set 5 | capoterra
# Processing Record 31 of Set 5 | sorland
# Processing Record 32 of Set 5 | tautira
# Processing Record 33 of Set 5 | andevoranto
# City not found. Skipping...
# Processing Record 34 of Set 5 | bonavista
# Processing Record 35 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 36 of Set 5 | seymchan
# Processing Record 37 of Set 5 | verkhoyansk
# Processing Record 38 of Set 5 | liaocheng
# Processing Record 39 of Set 5 | kichera
# Processing Record 40 of Set 5 | rawson
# Processing Record 41 of Set 5 | canutama
# Processing Record 42 of Set 5 | skjervoy
# Processing Record 43 of Set 5 | yantal
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 5 | kiama
# Processing Record 48 of Set 5 | tuban
# Processing Record 49 of Set 5 | urubicha
# Processing Record 50 of Set 5 | marienburg
# Processing Record 1 of Set 6 | barao de melgaco
# Processing Record 2 of Set 6 | baculin
# Processing Record 3 of Set 6 | benjamin aceval
# Processing Record 4 of Set 6 | yusva
# City not found. Skipping...
# Processing Record 5 of Set 6 | vestmanna
# Processing Record 6 of Set 6 | vanimo
# Processing Record 7 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 6 | leua
# Processing Record 9 of Set 6 | ardesen
# Processing Record 10 of Set 6 | lokosovo
# Processing Record 11 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 6 | constitucion
# Processing Record 13 of Set 6 | chuy
# Processing Record 14 of Set 6 | sompeta
# Processing Record 15 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 16 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 6 | qaqortoq
# Processing Record 18 of Set 6 | meulaboh
# Processing Record 19 of Set 6 | bilibino
# Processing Record 20 of Set 6 | quimper
# Processing Record 21 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 22 of Set 6 | broken hill
# Processing Record 23 of Set 6 | talnakh
# Processing Record 24 of Set 6 | imues
# Processing Record 25 of Set 6 | bethel
# Processing Record 26 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 6 | kimbe
# Processing Record 28 of Set 6 | hamilton
# Processing Record 29 of Set 6 | porto belo
# Processing Record 30 of Set 6 | eureka
# Processing Record 31 of Set 6 | chegdomyn
# Processing Record 32 of Set 6 | anloga
# Processing Record 33 of Set 6 | pilar
# Processing Record 34 of Set 6 | esperance
# Processing Record 35 of Set 6 | aklavik
# Processing Record 36 of Set 6 | karaman
# Processing Record 37 of Set 6 | cristalina
# Processing Record 38 of Set 6 | fort morgan
# Processing Record 39 of Set 6 | khatanga
# Processing Record 40 of Set 6 | domna
# Processing Record 41 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 6 | mananjary
# Processing Record 43 of Set 6 | hualmay
# Processing Record 44 of Set 6 | bom jesus da lapa
# Processing Record 45 of Set 6 | dubbo
# Processing Record 46 of Set 6 | ahipara
# Processing Record 47 of Set 6 | port blair
# Processing Record 48 of Set 6 | alice springs
# Processing Record 49 of Set 6 | pingliang
# Processing Record 50 of Set 6 | upernavik
# Processing Record 1 of Set 7 | walvis bay
# Processing Record 2 of Set 7 | ballitoville
# Processing Record 3 of Set 7 | sitka
# Processing Record 4 of Set 7 | maragogi
# Processing Record 5 of Set 7 | hirna
# Processing Record 6 of Set 7 | oriximina
# Processing Record 7 of Set 7 | uglekamensk
# Processing Record 8 of Set 7 | kirakira
# Processing Record 9 of Set 7 | moree
# Processing Record 10 of Set 7 | port moresby
# Processing Record 11 of Set 7 | zhigansk
# Processing Record 12 of Set 7 | pisco
# Processing Record 13 of Set 7 | makakilo city
# Processing Record 14 of Set 7 | te anau
# Processing Record 15 of Set 7 | souillac
# Processing Record 16 of Set 7 | limpapa
# Processing Record 17 of Set 7 | bristol
# Processing Record 18 of Set 7 | bonthe
# Processing Record 19 of Set 7 | lompoc
# Processing Record 20 of Set 7 | toora-khem
# Processing Record 21 of Set 7 | tocopilla
# Processing Record 22 of Set 7 | ojinaga
# Processing Record 23 of Set 7 | ngunguru
# Processing Record 24 of Set 7 | orangeburg
# Processing Record 25 of Set 7 | kayankulam
# Processing Record 26 of Set 7 | samoylovka
# Processing Record 27 of Set 7 | amapa
# Processing Record 28 of Set 7 | hami
# Processing Record 29 of Set 7 | port-gentil
# Processing Record 30 of Set 7 | soyo
# Processing Record 31 of Set 7 | pangai
# Processing Record 32 of Set 7 | karratha
# Processing Record 33 of Set 7 | san cristobal
# Processing Record 34 of Set 7 | bajos de haina
# Processing Record 35 of Set 7 | lata
# Processing Record 36 of Set 7 | mount gambier
# Processing Record 37 of Set 7 | saint-joseph
# Processing Record 38 of Set 7 | almeirim
# Processing Record 39 of Set 7 | katherine
# Processing Record 40 of Set 7 | hervey bay
# Processing Record 41 of Set 7 | ilulissat
# Processing Record 42 of Set 7 | pevek
# Processing Record 43 of Set 7 | pedernales
# Processing Record 44 of Set 7 | tharad
# Processing Record 45 of Set 7 | colac
# Processing Record 46 of Set 7 | rocha
# Processing Record 47 of Set 7 | kavieng
# Processing Record 48 of Set 7 | mecca
# Processing Record 49 of Set 7 | kemijarvi
# Processing Record 50 of Set 7 | ayan
# Processing Record 1 of Set 8 | atar
# Processing Record 2 of Set 8 | tay ninh
# Processing Record 3 of Set 8 | leningradskiy
# Processing Record 4 of Set 8 | vizinga
# Processing Record 5 of Set 8 | aguimes
# Processing Record 6 of Set 8 | nisia floresta
# Processing Record 7 of Set 8 | cheney
# Processing Record 8 of Set 8 | whitefish
# Processing Record 9 of Set 8 | cooma
# Processing Record 10 of Set 8 | hasaki
# Processing Record 11 of Set 8 | aleksandrov gay
# Processing Record 12 of Set 8 | dejen
# Processing Record 13 of Set 8 | lorengau
# Processing Record 14 of Set 8 | lyuban
# Processing Record 15 of Set 8 | lodja
# Processing Record 16 of Set 8 | ubauro
# Processing Record 17 of Set 8 | aldergrove
# Processing Record 18 of Set 8 | slusovice
# Processing Record 19 of Set 8 | severo-kurilsk
# Processing Record 20 of Set 8 | anta
# Processing Record 21 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 22 of Set 8 | matongo
# Processing Record 23 of Set 8 | reichenbach
# Processing Record 24 of Set 8 | talakan
# Processing Record 25 of Set 8 | cabo san lucas
# Processing Record 26 of Set 8 | dengzhou
# Processing Record 27 of Set 8 | alta floresta
# Processing Record 28 of Set 8 | dingle
# Processing Record 29 of Set 8 | nizhniy kuranakh
# Processing Record 30 of Set 8 | hostotipaquillo
# Processing Record 31 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 8 | viedma
# Processing Record 33 of Set 8 | salym
# Processing Record 34 of Set 8 | berbera
# Processing Record 35 of Set 8 | dipkarpaz
# City not found. Skipping...
# Processing Record 36 of Set 8 | praya
# Processing Record 37 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 38 of Set 8 | codrington
# Processing Record 39 of Set 8 | kuytun
# Processing Record 40 of Set 8 | paraiso
# Processing Record 41 of Set 8 | goderich
# Processing Record 42 of Set 8 | san lawrenz
# Processing Record 43 of Set 8 | margate
# Processing Record 44 of Set 8 | korsakov
# Processing Record 45 of Set 8 | binga
# Processing Record 46 of Set 8 | shache
# Processing Record 47 of Set 8 | trat
# Processing Record 48 of Set 8 | colesberg
# Processing Record 49 of Set 8 | bayburt
# Processing Record 50 of Set 8 | kavaratti
# Processing Record 1 of Set 9 | sorong
# Processing Record 2 of Set 9 | bandarbeyla
# Processing Record 3 of Set 9 | panguna
# Processing Record 4 of Set 9 | rassvet
# Processing Record 5 of Set 9 | portage
# Processing Record 6 of Set 9 | prabumulih
# Processing Record 7 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 9 | bilokurakyne
# Processing Record 9 of Set 9 | los llanos de aridane
# Processing Record 10 of Set 9 | evensk
# Processing Record 11 of Set 9 | coolum beach
# Processing Record 12 of Set 9 | egvekinot
# Processing Record 13 of Set 9 | almaznyy
# Processing Record 14 of Set 9 | lyubeshiv
# City not found. Skipping...
# Processing Record 15 of Set 9 | saint-pierre
# Processing Record 16 of Set 9 | asau
# Processing Record 17 of Set 9 | grindavik
# Processing Record 18 of Set 9 | severodvinsk
# Processing Record 19 of Set 9 | bukachacha
# Processing Record 20 of Set 9 | naze
# Processing Record 21 of Set 9 | artyom
# Processing Record 22 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 9 | batagay-alyta
# Processing Record 24 of Set 9 | point fortin
# Processing Record 25 of Set 9 | barroquinha
# Processing Record 26 of Set 9 | tartus
# Processing Record 27 of Set 9 | mujiayingzi
# Processing Record 28 of Set 9 | katobu
# Processing Record 29 of Set 9 | novopokrovka
# Processing Record 30 of Set 9 | dicabisagan
# Processing Record 31 of Set 9 | salinopolis
# Processing Record 32 of Set 9 | vilhena
# Processing Record 33 of Set 9 | bima
# Processing Record 34 of Set 9 | vinkovci
# Processing Record 35 of Set 9 | sao joao da barra
# Processing Record 36 of Set 9 | westport
# Processing Record 37 of Set 9 | bubaque
# Processing Record 38 of Set 9 | aswan
# Processing Record 39 of Set 9 | davila
# Processing Record 40 of Set 9 | san juan
# Processing Record 41 of Set 9 | geelong
# Processing Record 42 of Set 9 | winslow
# Processing Record 43 of Set 9 | mildura
# Processing Record 44 of Set 9 | adre
# Processing Record 45 of Set 9 | wagar
# Processing Record 46 of Set 9 | ballina
# Processing Record 47 of Set 9 | faya
# Processing Record 48 of Set 9 | ligayan
# Processing Record 49 of Set 9 | mount darwin
# Processing Record 50 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 1 of Set 10 | wuzhou
# Processing Record 2 of Set 10 | bereda
# Processing Record 3 of Set 10 | hobyo
# Processing Record 4 of Set 10 | xuddur
# Processing Record 5 of Set 10 | urumqi
# Processing Record 6 of Set 10 | malumfashi
# Processing Record 7 of Set 10 | kambove
# Processing Record 8 of Set 10 | haines junction
# Processing Record 9 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 10 | porto walter
# Processing Record 11 of Set 10 | hirara
# Processing Record 12 of Set 10 | porto empedocle
# Processing Record 13 of Set 10 | puri
# Processing Record 14 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 10 | port elizabeth
# Processing Record 16 of Set 10 | egersund
# Processing Record 17 of Set 10 | pangnirtung
# Processing Record 18 of Set 10 | vostok
# Processing Record 19 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 20 of Set 10 | nicoya
# Processing Record 21 of Set 10 | tevaitoa
# Processing Record 22 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 10 | tarnos
# Processing Record 24 of Set 10 | iqaluit
# Processing Record 25 of Set 10 | leh
# Processing Record 26 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 10 | hambantota
# Processing Record 28 of Set 10 | lensk
# Processing Record 29 of Set 10 | the valley
# Processing Record 30 of Set 10 | antofagasta
# Processing Record 31 of Set 10 | okhotsk
# Processing Record 32 of Set 10 | luwuk
# Processing Record 33 of Set 10 | badin
# Processing Record 34 of Set 10 | sabang
# Processing Record 35 of Set 10 | felanitx
# Processing Record 36 of Set 10 | vestmannaeyjar
# Processing Record 37 of Set 10 | kushiro
# Processing Record 38 of Set 10 | shimsk
# Processing Record 39 of Set 10 | manoharpur
# Processing Record 40 of Set 10 | gornopravdinsk
# Processing Record 41 of Set 10 | bridgend
# Processing Record 42 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 43 of Set 10 | mahajanga
# Processing Record 44 of Set 10 | tucurui
# Processing Record 45 of Set 10 | tazovskiy
# Processing Record 46 of Set 10 | killeen
# Processing Record 47 of Set 10 | qasigiannguit
# Processing Record 48 of Set 10 | lannion
# Processing Record 49 of Set 10 | tromso
# Processing Record 50 of Set 10 | torbay
# Processing Record 1 of Set 11 | kulhudhuffushi
# Processing Record 2 of Set 11 | notre-dame-du-lac
# Processing Record 3 of Set 11 | noyabrsk
# Processing Record 4 of Set 11 | cap malheureux
# Processing Record 5 of Set 11 | lufilufi
# Processing Record 6 of Set 11 | portel
# Processing Record 7 of Set 11 | killam
# Processing Record 8 of Set 11 | kodinsk
# Processing Record 9 of Set 11 | barranca
# Processing Record 10 of Set 11 | onega
# Processing Record 11 of Set 11 | renukut
# Processing Record 12 of Set 11 | royan
# Processing Record 13 of Set 11 | montague
# Processing Record 14 of Set 11 | coquimbo
# Processing Record 15 of Set 11 | weiser
# Processing Record 16 of Set 11 | steamboat springs
# Processing Record 17 of Set 11 | tema
# Processing Record 18 of Set 11 | acapulco
# Processing Record 19 of Set 11 | pontes e lacerda
# Processing Record 20 of Set 11 | comodoro rivadavia
# Processing Record 21 of Set 11 | yarmouth
# Processing Record 22 of Set 11 | mackay
# Processing Record 23 of Set 11 | rosetta
# Processing Record 24 of Set 11 | sherlovaya gora
# Processing Record 25 of Set 11 | dunedin
# Processing Record 26 of Set 11 | chanika
# Processing Record 27 of Set 11 | laguna
# Processing Record 28 of Set 11 | patrocinio
# Processing Record 29 of Set 11 | ginda
# Processing Record 30 of Set 11 | oranjemund
# Processing Record 31 of Set 11 | ust-nera
# Processing Record 32 of Set 11 | rethimnon
# Processing Record 33 of Set 11 | flin flon
# Processing Record 34 of Set 11 | san quintin
# Processing Record 35 of Set 11 | magadan
# Processing Record 36 of Set 11 | darnah
# Processing Record 37 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 11 | riyadh
# Processing Record 39 of Set 11 | matara
# Processing Record 40 of Set 11 | kramat
# Processing Record 41 of Set 11 | cabedelo
# Processing Record 42 of Set 11 | palmas
# Processing Record 43 of Set 11 | mizur
# Processing Record 44 of Set 11 | damietta
# Processing Record 45 of Set 11 | sola
# Processing Record 46 of Set 11 | jonava
# Processing Record 47 of Set 11 | althofen
# Processing Record 48 of Set 11 | araouane
# Processing Record 49 of Set 11 | sulangan
# Processing Record 50 of Set 11 | la huacana
# Processing Record 1 of Set 12 | bodden town
# Processing Record 2 of Set 12 | mokhotlong
# Processing Record 3 of Set 12 | verkhnyaya khava
# Processing Record 4 of Set 12 | golden
# Processing Record 5 of Set 12 | teguldet
# Processing Record 6 of Set 12 | chiredzi
# Processing Record 7 of Set 12 | tianjin
# Processing Record 8 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 9 of Set 12 | beloha
# Processing Record 10 of Set 12 | doha
# Processing Record 11 of Set 12 | feira de santana
# Processing Record 12 of Set 12 | nouadhibou
# Processing Record 13 of Set 12 | puerto narino
# Processing Record 14 of Set 12 | merritt island
# Processing Record 15 of Set 12 | kralendijk
# Processing Record 16 of Set 12 | green river
# Processing Record 17 of Set 12 | luau
# Processing Record 18 of Set 12 | camopi
# Processing Record 19 of Set 12 | sterling
# Processing Record 20 of Set 12 | arlit
# Processing Record 21 of Set 12 | sitrah
# Processing Record 22 of Set 12 | sheboygan
# Processing Record 23 of Set 12 | gizo
# Processing Record 24 of Set 12 | alihe
# Processing Record 25 of Set 12 | cauquenes
# Processing Record 26 of Set 12 | chandbali
# Processing Record 27 of Set 12 | touros
# Processing Record 28 of Set 12 | okato
# Processing Record 29 of Set 12 | ixtapa
# Processing Record 30 of Set 12 | saint-francois
# Processing Record 31 of Set 12 | tlacotepec
# Processing Record 32 of Set 12 | tracy
# Processing Record 33 of Set 12 | sandakan
# Processing Record 34 of Set 12 | capaci
# Processing Record 35 of Set 12 | bontang
# Processing Record 36 of Set 12 | mattru
# Processing Record 37 of Set 12 | beira
# Processing Record 38 of Set 12 | buribay
# Processing Record 39 of Set 12 | san clemente
# Processing Record 40 of Set 12 | kloulklubed
# Processing Record 41 of Set 12 | xalpatlahuac
# Processing Record 42 of Set 12 | clarence town
# Processing Record 43 of Set 12 | cravo norte
# Processing Record 44 of Set 12 | vila velha
# Processing Record 45 of Set 12 | middelburg
# Processing Record 46 of Set 12 | jumla
# Processing Record 47 of Set 12 | alyangula
# Processing Record 48 of Set 12 | neuquen
# Processing Record 49 of Set 12 | kruisfontein
# Processing Record 50 of Set 12 | conakry
# Processing Record 1 of Set 13 | chiguiri arriba
# City not found. Skipping...
# Processing Record 2 of Set 13 | aripuana
# Processing Record 3 of Set 13 | kenai
# Processing Record 4 of Set 13 | terme
# Processing Record 5 of Set 13 | san rafael
# Processing Record 6 of Set 13 | ushtobe
# Processing Record 7 of Set 13 | thinadhoo
# Processing Record 8 of Set 13 | hof
# Processing Record 9 of Set 13 | thanh hoa
# Processing Record 10 of Set 13 | gaoyou
# Processing Record 11 of Set 13 | buala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 65.32,
#   'Humidity': 64,
#   'Cloudiness': 93,
#   'Wind Speed': 21.63,
#   'Country': 'ZA',
#   'Date': '2021-11-25 16:14:13'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 80.19,
#   'Humidity': 82,
#   'Cloudiness': 61,
#   'Wind Speed': 4.92,
#   'Country': 'RE',
#   'Date': '2021-11-25 16:14:14'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 75.49,
#   'Humidity': 77,
#   'Cloudiness': 13,
#   'Wind Speed': 13.2,
#   'Country': 'PF',
#   'Date': '2021-11-25 16:14:14'},
#  {'City': 'Caxito',
#   'Lat': -8.5785,
#   'Lng': 13.6643,
#   'Max Temp': 83.05,
#   'Humidity': 71,
#   'Cloudiness': 78,
#   'Wind Speed': 6.85,
#   'Country': 'AO',
#   'Date': '2021-11-25 16:14:15'},
#  {'City': 'Yuncheng',
#   'Lat': 35.0231,
#   'Lng': 110.9928,
#   'Max Temp': 44.62,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 2.28,
#   'Country': 'CN',
#   'Date': '2021-11-25 16:14:15'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 61.66,
#   'Humidity': 73,
#   'Cloudiness': 93,
#   'Wind Speed': 30.94,
#   'Country': 'PT',
#   'Date': '2021-11-25 16:14:15'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 49.62,
#   'Humidity': 61,
#   'Cloudiness': 86,
#   'Wind Speed': 2.48,
#   'Country': 'AR',
#   'Date': '2021-11-25 16:10:11'},
#  {'City': 'Chumikan',
#   'Lat': 54.7183,
#   'Lng': 135.315,
#   'Max Temp': 14.99,
#   'Humidity': 91,
#   'Cloudiness': 92,
#   'Wind Speed': 6.38,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:14:16'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 80.15,
#   'Humidity': 47,
#   'Cloudiness': 77,
#   'Wind Speed': 8.46,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:14:16'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 40.12,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2021-11-25 16:11:54'},
#  {'City': 'Yerbogachen',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 9.84,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 4.59,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:14:16'},
#  {'City': 'Zaysan',
#   'Lat': 47.4667,
#   'Lng': 84.8667,
#   'Max Temp': 37.2,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 4.27,
#   'Country': 'KZ',
#   'Date': '2021-11-25 16:14:17'},
#  {'City': 'Syamzha',
#   'Lat': 60.0158,
#   'Lng': 41.0614,
#   'Max Temp': 23.67,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 9.06,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:14:17'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 66.04,
#   'Humidity': 79,
#   'Cloudiness': 56,
#   'Wind Speed': 11.56,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:14:17'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 7.41,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:13:02'},
#  {'City': 'Gold Coast',
#   'Lat': -28,
#   'Lng': 153.4333,
#   'Max Temp': 75.2,
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:14:18'},
#  {'City': 'Mitsamiouli',
#   'Lat': -11.3847,
#   'Lng': 43.2844,
#   'Max Temp': 80.8,
#   'Humidity': 74,
#   'Cloudiness': 66,
#   'Wind Speed': 5.77,
#   'Country': 'KM',
#   'Date': '2021-11-25 16:14:18'},
#  {'City': 'Rypefjord',
#   'Lat': 70.6333,
#   'Lng': 23.6667,
#   'Max Temp': 23.47,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'NO',
#   'Date': '2021-11-25 16:14:19'},
#  {'City': 'College',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': -4.34,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-11-25 16:14:19'},
#  {'City': 'Melilla',
#   'Lat': 35.2937,
#   'Lng': -2.9383,
#   'Max Temp': 57.58,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'ES',
#   'Date': '2021-11-25 16:14:19'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -9.38,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': '2021-11-25 16:14:20'},
#  {'City': 'Umm Lajj',
#   'Lat': 25.0213,
#   'Lng': 37.2685,
#   'Max Temp': 77.81,
#   'Humidity': 54,
#   'Cloudiness': 12,
#   'Wind Speed': 10.29,
#   'Country': 'SA',
#   'Date': '2021-11-25 16:14:20'},
#  {'City': 'Seoul',
#   'Lat': 37.5683,
#   'Lng': 126.9778,
#   'Max Temp': 36.84,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 4.41,
#   'Country': 'KR',
#   'Date': '2021-11-25 16:14:20'},
#  {'City': 'Ugoofaaru',
#   'Lat': 5.6667,
#   'Lng': 73,
#   'Max Temp': 80.98,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'MV',
#   'Date': '2021-11-25 16:14:20'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -4.5,
#   'Humidity': 58,
#   'Cloudiness': 13,
#   'Wind Speed': 5.7,
#   'Country': 'GL',
#   'Date': '2021-11-25 16:14:21'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 77.07,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:14:21'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 75.27,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-11-25 16:14:21'},
#  {'City': 'Narrabri',
#   'Lat': -30.3167,
#   'Lng': 149.7833,
#   'Max Temp': 68.09,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:14:22'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 53.11,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 29.93,
#   'Country': 'CL',
#   'Date': '2021-11-25 16:10:45'},
#  {'City': 'Baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 0.97,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 1.54,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:14:22'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -4.49,
#   'Humidity': 85,
#   'Cloudiness': 5,
#   'Wind Speed': 3.62,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:14:23'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.37,
#   'Humidity': 80,
#   'Cloudiness': 33,
#   'Wind Speed': 17.72,
#   'Country': 'PF',
#   'Date': '2021-11-25 16:14:23'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': -0.78,
#   'Humidity': 82,
#   'Cloudiness': 57,
#   'Wind Speed': 7.18,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:12:16'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -0.4,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:14:23'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 73.56,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'TO',
#   'Date': '2021-11-25 16:14:24'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 75.52,
#   'Humidity': 72,
#   'Cloudiness': 32,
#   'Wind Speed': 18.52,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:14:24'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 63.88,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 11.99,
#   'Country': 'AR',
#   'Date': '2021-11-25 16:14:24'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 57.7,
#   'Humidity': 43,
#   'Cloudiness': 98,
#   'Wind Speed': 5.84,
#   'Country': 'US',
#   'Date': '2021-11-25 16:14:25'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 77.02,
#   'Humidity': 85,
#   'Cloudiness': 51,
#   'Wind Speed': 3.78,
#   'Country': 'ID',
#   'Date': '2021-11-25 16:14:25'},
#  {'City': 'Fernley',
#   'Lat': 39.608,
#   'Lng': -119.2518,
#   'Max Temp': 45.3,
#   'Humidity': 44,
#   'Cloudiness': 11,
#   'Wind Speed': 3.51,
#   'Country': 'US',
#   'Date': '2021-11-25 16:12:58'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 47.12,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'UZ',
#   'Date': '2021-11-25 16:14:25'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 43.36,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-11-25 16:14:26'},
#  {'City': 'Buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 75.51,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 11.03,
#   'Country': 'SA',
#   'Date': '2021-11-25 16:14:26'},
#  {'City': 'Dukat',
#   'Lat': 62.55,
#   'Lng': 155.55,
#   'Max Temp': -30.28,
#   'Humidity': 100,
#   'Cloudiness': 59,
#   'Wind Speed': 4.16,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:14:26'},
#  {'City': 'Marystown',
#   'Lat': 47.1666,
#   'Lng': -55.1483,
#   'Max Temp': 52.86,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:14:27'},
#  {'City': 'Guararema',
#   'Lat': -23.415,
#   'Lng': -46.035,
#   'Max Temp': 88.43,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 1.81,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:14:27'},
#  {'City': 'Inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 75.18,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'MZ',
#   'Date': '2021-11-25 16:15:27'},
#  {'City': 'Ishigaki',
#   'Lat': 24.3448,
#   'Lng': 124.1572,
#   'Max Temp': 74.73,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 19.13,
#   'Country': 'JP',
#   'Date': '2021-11-25 16:15:28'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 64.8,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 25.32,
#   'Country': 'PT',
#   'Date': '2021-11-25 16:15:28'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 48.06,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:14:55'},
#  {'City': 'Kjollefjord',
#   'Lat': 70.9457,
#   'Lng': 27.3465,
#   'Max Temp': 24.85,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'NO',
#   'Date': '2021-11-25 16:15:28'},
#  {'City': 'Olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 38.48,
#   'Humidity': 72,
#   'Cloudiness': 51,
#   'Wind Speed': 19.93,
#   'Country': 'IS',
#   'Date': '2021-11-25 16:15:29'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 59.04,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 19.04,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:15:29'},
#  {'City': 'Artyshta',
#   'Lat': 54.1222,
#   'Lng': 86.2909,
#   'Max Temp': 32.16,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 11.61,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:15:29'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 66.52,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 9.17,
#   'Country': 'ZA',
#   'Date': '2021-11-25 16:15:29'},
#  {'City': 'Albufeira',
#   'Lat': 37.0882,
#   'Lng': -8.2503,
#   'Max Temp': 53.44,
#   'Humidity': 72,
#   'Cloudiness': 43,
#   'Wind Speed': 12.95,
#   'Country': 'PT',
#   'Date': '2021-11-25 16:15:30'},
#  {'City': 'Huilong',
#   'Lat': 31.8111,
#   'Lng': 121.655,
#   'Max Temp': 56.03,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 2.44,
#   'Country': 'CN',
#   'Date': '2021-11-25 16:15:30'},
#  {'City': 'Hounde',
#   'Lat': 11.5,
#   'Lng': -3.5167,
#   'Max Temp': 99.14,
#   'Humidity': 9,
#   'Cloudiness': 67,
#   'Wind Speed': 7.76,
#   'Country': 'BF',
#   'Date': '2021-11-25 16:15:30'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 66.34,
#   'Humidity': 68,
#   'Cloudiness': 7,
#   'Wind Speed': 4.09,
#   'Country': 'MX',
#   'Date': '2021-11-25 16:15:31'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 86.11,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 25.79,
#   'Country': 'ZA',
#   'Date': '2021-11-25 16:12:03'},
#  {'City': 'Hurghada',
#   'Lat': 27.2574,
#   'Lng': 33.8129,
#   'Max Temp': 73.99,
#   'Humidity': 52,
#   'Cloudiness': 5,
#   'Wind Speed': 10.09,
#   'Country': 'EG',
#   'Date': '2021-11-25 16:15:31'},
#  {'City': 'Arsk',
#   'Lat': 56.0915,
#   'Lng': 49.8778,
#   'Max Temp': 29.98,
#   'Humidity': 91,
#   'Cloudiness': 91,
#   'Wind Speed': 10.54,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:15:31'},
#  {'City': 'Abaza',
#   'Lat': 52.655,
#   'Lng': 90.0928,
#   'Max Temp': 33.57,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.36,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:15:32'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -0.56,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 11.65,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:15:32'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 63.75,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 29.24,
#   'Country': 'PT',
#   'Date': '2021-11-25 16:15:32'},
#  {'City': 'Lashio',
#   'Lat': 22.9333,
#   'Lng': 97.75,
#   'Max Temp': 57.72,
#   'Humidity': 97,
#   'Cloudiness': 0,
#   'Wind Speed': 1.45,
#   'Country': 'MM',
#   'Date': '2021-11-25 16:15:33'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 12.04,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 18.41,
#   'Country': 'SJ',
#   'Date': '2021-11-25 16:15:33'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 76.95,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-11-25 16:15:33'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 84.16,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:15:33'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 75.52,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Date': '2021-11-25 16:15:34'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 66.15,
#   'Humidity': 74,
#   'Cloudiness': 55,
#   'Wind Speed': 10.89,
#   'Country': 'NA',
#   'Date': '2021-11-25 16:15:34'},
#  {'City': 'Northam',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 45.01,
#   'Humidity': 68,
#   'Cloudiness': 79,
#   'Wind Speed': 11.59,
#   'Country': 'GB',
#   'Date': '2021-11-25 16:15:35'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 78.91,
#   'Humidity': 68,
#   'Cloudiness': 11,
#   'Wind Speed': 4.21,
#   'Country': 'MU',
#   'Date': '2021-11-25 16:15:35'},
#  {'City': 'Cuamba',
#   'Lat': -14.8031,
#   'Lng': 36.5372,
#   'Max Temp': 74.05,
#   'Humidity': 80,
#   'Cloudiness': 65,
#   'Wind Speed': 6.93,
#   'Country': 'MZ',
#   'Date': '2021-11-25 16:15:35'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 8.65,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 7.81,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:15:35'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.09,
#   'Humidity': 70,
#   'Cloudiness': 77,
#   'Wind Speed': 15.3,
#   'Country': 'MV',
#   'Date': '2021-11-25 16:15:36'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 68.68,
#   'Humidity': 100,
#   'Cloudiness': 2,
#   'Wind Speed': 5.57,
#   'Country': 'IL',
#   'Date': '2021-11-25 16:15:36'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 78.57,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 8.21,
#   'Country': 'CV',
#   'Date': '2021-11-25 16:15:36'},
#  {'City': 'Ankazobe',
#   'Lat': -18.3167,
#   'Lng': 47.1167,
#   'Max Temp': 68.41,
#   'Humidity': 75,
#   'Cloudiness': 95,
#   'Wind Speed': 8.57,
#   'Country': 'MG',
#   'Date': '2021-11-25 16:15:37'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 37.56,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.95,
#   'Country': 'GL',
#   'Date': '2021-11-25 16:15:37'},
#  {'City': 'Labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 78.3,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 11.52,
#   'Country': 'ID',
#   'Date': '2021-11-25 16:15:37'},
#  {'City': 'Awbari',
#   'Lat': 26.5921,
#   'Lng': 12.7805,
#   'Max Temp': 81.77,
#   'Humidity': 21,
#   'Cloudiness': 1,
#   'Wind Speed': 12.77,
#   'Country': 'LY',
#   'Date': '2021-11-25 16:15:38'},
#  {'City': 'Hauterive',
#   'Lat': 46.0901,
#   'Lng': 3.4459,
#   'Max Temp': 39.96,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 6.08,
#   'Country': 'FR',
#   'Date': '2021-11-25 16:15:38'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 47.52,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-11-25 16:15:38'},
#  {'City': 'Hoa Binh',
#   'Lat': 20.8133,
#   'Lng': 105.3383,
#   'Max Temp': 62.49,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 2.01,
#   'Country': 'VN',
#   'Date': '2021-11-25 16:15:39'},
#  {'City': 'Caloundra',
#   'Lat': -26.8,
#   'Lng': 153.1333,
#   'Max Temp': 74.89,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:15:39'},
#  {'City': 'La Macarena',
#   'Lat': 2.1837,
#   'Lng': -73.7849,
#   'Max Temp': 74.16,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Country': 'CO',
#   'Date': '2021-11-25 16:15:39'},
#  {'City': 'Samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 82.71,
#   'Humidity': 79,
#   'Cloudiness': 79,
#   'Wind Speed': 11.72,
#   'Country': 'PG',
#   'Date': '2021-11-25 16:15:40'},
#  {'City': 'Macusani',
#   'Lat': -14.0833,
#   'Lng': -70.4333,
#   'Max Temp': 49.55,
#   'Humidity': 58,
#   'Cloudiness': 99,
#   'Wind Speed': 7.7,
#   'Country': 'PE',
#   'Date': '2021-11-25 16:15:40'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 19.63,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:15:40'},
#  {'City': 'Tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 84.31,
#   'Humidity': 73,
#   'Cloudiness': 38,
#   'Wind Speed': 8.21,
#   'Country': 'ID',
#   'Date': '2021-11-25 16:15:41'},
#  {'City': 'Joshimath',
#   'Lat': 30.5667,
#   'Lng': 79.5667,
#   'Max Temp': 46.71,
#   'Humidity': 38,
#   'Cloudiness': 5,
#   'Wind Speed': 6.87,
#   'Country': 'IN',
#   'Date': '2021-11-25 16:15:41'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 68.72,
#   'Humidity': 60,
#   'Cloudiness': 89,
#   'Wind Speed': 3.67,
#   'Country': 'PT',
#   'Date': '2021-11-25 16:16:41'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 83.01,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'BB',
#   'Date': '2021-11-25 16:16:42'},
#  {'City': 'Thunder Bay',
#   'Lat': 48.4001,
#   'Lng': -89.3168,
#   'Max Temp': 13.55,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 11.99,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:13:28'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 76.84,
#   'Humidity': 79,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-11-25 16:16:42'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 80.58,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:14:42'},
#  {'City': 'Coos Bay',
#   'Lat': 43.3665,
#   'Lng': -124.2179,
#   'Max Temp': 40.93,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Date': '2021-11-25 16:14:05'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 11.77,
#   'Humidity': 77,
#   'Cloudiness': 81,
#   'Wind Speed': 3.36,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:16:43'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 72.41,
#   'Humidity': 61,
#   'Cloudiness': 2,
#   'Wind Speed': 13,
#   'Country': 'AO',
#   'Date': '2021-11-25 16:16:43'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -18.36,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:16:43'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 62.31,
#   'Humidity': 94,
#   'Cloudiness': 78,
#   'Wind Speed': 1.79,
#   'Country': 'TL',
#   'Date': '2021-11-25 16:16:44'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 57.43,
#   'Humidity': 69,
#   'Cloudiness': 93,
#   'Wind Speed': 13.73,
#   'Country': 'NZ',
#   'Date': '2021-11-25 16:16:44'},
#  {'City': 'Dauphin',
#   'Lat': 51.1494,
#   'Lng': -100.0502,
#   'Max Temp': 1.54,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:16:44'},
#  {'City': 'Maniitsoq',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 23.5,
#   'Humidity': 78,
#   'Cloudiness': 92,
#   'Wind Speed': 12.28,
#   'Country': 'GL',
#   'Date': '2021-11-25 16:16:45'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 78.75,
#   'Humidity': 90,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'MY',
#   'Date': '2021-11-25 16:16:19'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 46.81,
#   'Humidity': 67,
#   'Cloudiness': 96,
#   'Wind Speed': 1.32,
#   'Country': 'US',
#   'Date': '2021-11-25 16:16:15'},
#  {'City': 'Muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 58.23,
#   'Humidity': 63,
#   'Cloudiness': 52,
#   'Wind Speed': 15.66,
#   'Country': 'ES',
#   'Date': '2021-11-25 16:16:45'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 17.35,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 20.71,
#   'Country': 'NO',
#   'Date': '2021-11-25 16:16:45'},
#  {'City': 'Severnyy',
#   'Lat': 50.677,
#   'Lng': 36.5532,
#   'Max Temp': 35.64,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:16:46'},
#  {'City': 'Cradock',
#   'Lat': -32.1642,
#   'Lng': 25.6192,
#   'Max Temp': 64.47,
#   'Humidity': 53,
#   'Cloudiness': 50,
#   'Wind Speed': 19.77,
#   'Country': 'ZA',
#   'Date': '2021-11-25 16:16:46'},
#  {'City': 'Biltine',
#   'Lat': 14.5333,
#   'Lng': 20.9167,
#   'Max Temp': 85.82,
#   'Humidity': 10,
#   'Cloudiness': 5,
#   'Wind Speed': 9.46,
#   'Country': 'TD',
#   'Date': '2021-11-25 16:16:46'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.18,
#   'Humidity': 73,
#   'Cloudiness': 51,
#   'Wind Speed': 15.73,
#   'Country': 'KI',
#   'Date': '2021-11-25 16:16:47'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 65.97,
#   'Humidity': 94,
#   'Cloudiness': 62,
#   'Wind Speed': 1.14,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:16:47'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 32.16,
#   'Humidity': 55,
#   'Cloudiness': 3,
#   'Wind Speed': 14.34,
#   'Country': 'GL',
#   'Date': '2021-11-25 16:16:47'},
#  {'City': 'Sisimiut',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 22.32,
#   'Humidity': 76,
#   'Cloudiness': 97,
#   'Wind Speed': 12.73,
#   'Country': 'GL',
#   'Date': '2021-11-25 16:16:48'},
#  {'City': 'Esmeraldas',
#   'Lat': -19.7625,
#   'Lng': -44.3139,
#   'Max Temp': 87.91,
#   'Humidity': 49,
#   'Cloudiness': 22,
#   'Wind Speed': 4.43,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:16:48'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 76.89,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 31.97,
#   'Country': 'ZA',
#   'Date': '2021-11-25 16:16:48'},
#  {'City': 'La Ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 12.45,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:16:48'},
#  {'City': 'Kyra',
#   'Lat': 49.5776,
#   'Lng': 111.9753,
#   'Max Temp': 5.95,
#   'Humidity': 90,
#   'Cloudiness': 33,
#   'Wind Speed': 3.8,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:16:49'},
#  {'City': 'Bireun',
#   'Lat': 5.203,
#   'Lng': 96.7009,
#   'Max Temp': 77.81,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.77,
#   'Country': 'ID',
#   'Date': '2021-11-25 16:16:49'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 55.71,
#   'Humidity': 75,
#   'Cloudiness': 94,
#   'Wind Speed': 9.62,
#   'Country': 'NZ',
#   'Date': '2021-11-25 16:16:49'},
#  {'City': 'Miraflores',
#   'Lat': 19.2167,
#   'Lng': -98.8083,
#   'Max Temp': 63.36,
#   'Humidity': 58,
#   'Cloudiness': 21,
#   'Wind Speed': 1.32,
#   'Country': 'MX',
#   'Date': '2021-11-25 16:16:50'},
#  {'City': 'Yaan',
#   'Lat': 7.3833,
#   'Lng': 8.5667,
#   'Max Temp': 95.5,
#   'Humidity': 27,
#   'Cloudiness': 28,
#   'Wind Speed': 5.06,
#   'Country': 'NG',
#   'Date': '2021-11-25 16:16:50'},
#  {'City': 'Huarmey',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 70.81,
#   'Humidity': 79,
#   'Cloudiness': 86,
#   'Wind Speed': 10.02,
#   'Country': 'PE',
#   'Date': '2021-11-25 16:16:50'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': -14.91,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-11-25 16:13:03'},
#  {'City': 'Nakonde',
#   'Lat': -9.3421,
#   'Lng': 32.745,
#   'Max Temp': 67.89,
#   'Humidity': 69,
#   'Cloudiness': 82,
#   'Wind Speed': 5.1,
#   'Country': 'ZM',
#   'Date': '2021-11-25 16:16:51'},
#  {'City': 'Ayagoz',
#   'Lat': 47.9714,
#   'Lng': 80.4392,
#   'Max Temp': 38.79,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 17.72,
#   'Country': 'KZ',
#   'Date': '2021-11-25 16:16:51'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 75.02,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 16.67,
#   'Country': 'ZA',
#   'Date': '2021-11-25 16:16:51'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 56.01,
#   'Humidity': 50,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CL',
#   'Date': '2021-11-25 16:14:04'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 78.76,
#   'Humidity': 86,
#   'Cloudiness': 57,
#   'Wind Speed': 5.99,
#   'Country': 'EC',
#   'Date': '2021-11-25 16:16:52'},
#  {'City': 'Meiganga',
#   'Lat': 6.5167,
#   'Lng': 14.3,
#   'Max Temp': 83.93,
#   'Humidity': 26,
#   'Cloudiness': 76,
#   'Wind Speed': 4.76,
#   'Country': 'CM',
#   'Date': '2021-11-25 16:16:52'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 69.33,
#   'Humidity': 70,
#   'Cloudiness': 4,
#   'Wind Speed': 3,
#   'Country': 'HK',
#   'Date': '2021-11-25 16:15:28'},
#  {'City': 'Marawi',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 66.65,
#   'Humidity': 94,
#   'Cloudiness': 73,
#   'Wind Speed': 1.72,
#   'Country': 'PH',
#   'Date': '2021-11-25 16:16:52'},
#  {'City': 'Imeni Poliny Osipenko',
#   'Lat': 52.4201,
#   'Lng': 136.4853,
#   'Max Temp': 27.43,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 21.63,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:16:54'},
#  {'City': 'Clinton',
#   'Lat': 42.587,
#   'Lng': -82.9199,
#   'Max Temp': 45.95,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-11-25 16:13:06'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 58.71,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 9.04,
#   'Country': 'NZ',
#   'Date': '2021-11-25 16:16:54'},
#  {'City': 'Kasempa',
#   'Lat': -13.4584,
#   'Lng': 25.8338,
#   'Max Temp': 73.02,
#   'Humidity': 60,
#   'Cloudiness': 95,
#   'Wind Speed': 7.96,
#   'Country': 'ZM',
#   'Date': '2021-11-25 16:16:55'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 42.87,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 12.37,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:17:55'},
#  {'City': 'Barkot',
#   'Lat': 30.8167,
#   'Lng': 78.2,
#   'Max Temp': 49.87,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 4.05,
#   'Country': 'IN',
#   'Date': '2021-11-25 16:17:55'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 63.01,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:17:56'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 68.29,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 28.05,
#   'Country': 'ZA',
#   'Date': '2021-11-25 16:17:56'},
#  {'City': 'Machinga',
#   'Lat': -15.1685,
#   'Lng': 35.3,
#   'Max Temp': 73.45,
#   'Humidity': 77,
#   'Cloudiness': 95,
#   'Wind Speed': 4.68,
#   'Country': 'MW',
#   'Date': '2021-11-25 16:17:56'},
#  {'City': 'Waipawa',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 57.04,
#   'Humidity': 72,
#   'Cloudiness': 30,
#   'Wind Speed': 13.11,
#   'Country': 'NZ',
#   'Date': '2021-11-25 16:17:56'},
#  {'City': 'Eston',
#   'Lat': 51.1501,
#   'Lng': -108.7514,
#   'Max Temp': 30.09,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 6.33,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:17:57'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 81.07,
#   'Humidity': 78,
#   'Cloudiness': 18,
#   'Wind Speed': 15.41,
#   'Country': 'PF',
#   'Date': '2021-11-25 16:17:57'},
#  {'City': 'Dekar',
#   'Lat': -21.5333,
#   'Lng': 21.9333,
#   'Max Temp': 93.15,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 11.18,
#   'Country': 'BW',
#   'Date': '2021-11-25 16:17:57'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 79.05,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'MU',
#   'Date': '2021-11-25 16:17:58'},
#  {'City': 'Lagos',
#   'Lat': 6.5833,
#   'Lng': 3.75,
#   'Max Temp': 88.12,
#   'Humidity': 69,
#   'Cloudiness': 82,
#   'Wind Speed': 7.45,
#   'Country': 'NG',
#   'Date': '2021-11-25 16:16:29'},
#  {'City': 'Shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 54.1,
#   'Humidity': 64,
#   'Cloudiness': 2,
#   'Wind Speed': 28.39,
#   'Country': 'JP',
#   'Date': '2021-11-25 16:17:58'},
#  {'City': 'Altagracia De Orituco',
#   'Lat': 9.8601,
#   'Lng': -66.3814,
#   'Max Temp': 83.05,
#   'Humidity': 69,
#   'Cloudiness': 91,
#   'Wind Speed': 3.89,
#   'Country': 'VE',
#   'Date': '2021-11-25 16:17:58'},
#  {'City': 'Bada',
#   'Lat': 51.392,
#   'Lng': 109.8717,
#   'Max Temp': 11.8,
#   'Humidity': 91,
#   'Cloudiness': 83,
#   'Wind Speed': 3.06,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:17:59'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 77.05,
#   'Humidity': 79,
#   'Cloudiness': 97,
#   'Wind Speed': 3.62,
#   'Country': 'ID',
#   'Date': '2021-11-25 16:17:59'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 17.11,
#   'Humidity': 57,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Date': '2021-11-25 16:14:05'},
#  {'City': 'Dalbandin',
#   'Lat': 28.8947,
#   'Lng': 64.4101,
#   'Max Temp': 62.92,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 7.36,
#   'Country': 'PK',
#   'Date': '2021-11-25 16:18:00'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 61.9,
#   'Humidity': 68,
#   'Cloudiness': 3,
#   'Wind Speed': 9.33,
#   'Country': 'CL',
#   'Date': '2021-11-25 16:18:00'},
#  {'City': 'Itanagar',
#   'Lat': 27.1,
#   'Lng': 93.6167,
#   'Max Temp': 59.22,
#   'Humidity': 69,
#   'Cloudiness': 15,
#   'Wind Speed': 4.7,
#   'Country': 'IN',
#   'Date': '2021-11-25 16:18:00'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 41.02,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 19.57,
#   'Country': 'IS',
#   'Date': '2021-11-25 16:18:01'},
#  {'City': 'Mushie',
#   'Lat': -3.0167,
#   'Lng': 16.9,
#   'Max Temp': 76.3,
#   'Humidity': 93,
#   'Cloudiness': 70,
#   'Wind Speed': 2.91,
#   'Country': 'CD',
#   'Date': '2021-11-25 16:18:01'},
#  {'City': 'Necochea',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 70.03,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 9.86,
#   'Country': 'AR',
#   'Date': '2021-11-25 16:18:01'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 73.72,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 15.3,
#   'Country': 'NC',
#   'Date': '2021-11-25 16:18:02'},
#  {'City': 'Wembley',
#   'Lat': -31.9333,
#   'Lng': 115.8,
#   'Max Temp': 74.08,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:17:47'},
#  {'City': 'Columbus',
#   'Lat': 39.9612,
#   'Lng': -82.9988,
#   'Max Temp': 46.92,
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-11-25 16:13:51'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 75.61,
#   'Humidity': 84,
#   'Cloudiness': 50,
#   'Wind Speed': 3.89,
#   'Country': 'VU',
#   'Date': '2021-11-25 16:18:02'},
#  {'City': 'Kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 77.14,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 6.24,
#   'Country': 'LK',
#   'Date': '2021-11-25 16:18:03'},
#  {'City': 'Jinchang',
#   'Lat': 38.4953,
#   'Lng': 102.1739,
#   'Max Temp': 34.23,
#   'Humidity': 28,
#   'Cloudiness': 7,
#   'Wind Speed': 3.22,
#   'Country': 'CN',
#   'Date': '2021-11-25 16:18:03'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 82.11,
#   'Humidity': 54,
#   'Cloudiness': 37,
#   'Wind Speed': 8.79,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:18:03'},
#  {'City': 'Yumen',
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 29.19,
#   'Humidity': 33,
#   'Cloudiness': 3,
#   'Wind Speed': 7.54,
#   'Country': 'CN',
#   'Date': '2021-11-25 16:18:04'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -31.09,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 5.35,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:18:04'},
#  {'City': 'Valparaiso',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 73.63,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'CL',
#   'Date': '2021-11-25 16:13:58'},
#  {'City': 'Tuensang',
#   'Lat': 26.2833,
#   'Lng': 94.8333,
#   'Max Temp': 53.1,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 3.56,
#   'Country': 'IN',
#   'Date': '2021-11-25 16:18:05'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 47.7,
#   'Humidity': 60,
#   'Cloudiness': 36,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:18:05'},
#  {'City': 'Loralai',
#   'Lat': 30.3705,
#   'Lng': 68.598,
#   'Max Temp': 57.24,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'PK',
#   'Date': '2021-11-25 16:18:05'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 75.25,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'CK',
#   'Date': '2021-11-25 16:18:06'},
#  {'City': 'Qinhuangdao',
#   'Lat': 39.9317,
#   'Lng': 119.5883,
#   'Max Temp': 39.43,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 3.65,
#   'Country': 'CN',
#   'Date': '2021-11-25 16:16:32'},
#  {'City': 'Kungurtug',
#   'Lat': 50.5994,
#   'Lng': 97.5228,
#   'Max Temp': 14.38,
#   'Humidity': 88,
#   'Cloudiness': 70,
#   'Wind Speed': 2.86,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:18:06'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 89.91,
#   'Humidity': 53,
#   'Cloudiness': 89,
#   'Wind Speed': 17.78,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:18:06'},
#  {'City': 'Conde',
#   'Lat': -7.2597,
#   'Lng': -34.9075,
#   'Max Temp': 89.06,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:18:07'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 34.02,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.99,
#   'Country': 'GL',
#   'Date': '2021-11-25 16:18:07'},
#  {'City': 'Bucerias',
#   'Lat': 20.75,
#   'Lng': -105.3333,
#   'Max Temp': 78.98,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'MX',
#   'Date': '2021-11-25 16:18:08'},
#  {'City': 'Ribeira Brava',
#   'Lat': 32.65,
#   'Lng': -17.0667,
#   'Max Temp': 69.71,
#   'Humidity': 61,
#   'Cloudiness': 90,
#   'Wind Speed': 4.65,
#   'Country': 'PT',
#   'Date': '2021-11-25 16:18:08'},
#  {'City': 'Vershino-Shakhtaminskiy',
#   'Lat': 51.3012,
#   'Lng': 117.8868,
#   'Max Temp': -6.16,
#   'Humidity': 92,
#   'Cloudiness': 30,
#   'Wind Speed': 1.97,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:19:08'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 76.84,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 4.99,
#   'Country': 'NC',
#   'Date': '2021-11-25 16:19:09'},
#  {'City': 'Carutapera',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 87.53,
#   'Humidity': 61,
#   'Cloudiness': 98,
#   'Wind Speed': 9.69,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:19:09'},
#  {'City': 'Juneau',
#   'Lat': 58.3019,
#   'Lng': -134.4197,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-11-25 16:19:09'},
#  {'City': 'Kutum',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 72.66,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 10.42,
#   'Country': 'SD',
#   'Date': '2021-11-25 16:19:10'},
#  {'City': 'Budogoshch',
#   'Lat': 59.2816,
#   'Lng': 32.4707,
#   'Max Temp': 38.48,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 13.18,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:19:10'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 63.54,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'ZA',
#   'Date': '2021-11-25 16:19:10'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': -11.54,
#   'Humidity': 91,
#   'Cloudiness': 47,
#   'Wind Speed': 9.19,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:19:11'},
#  {'City': 'Jizan',
#   'Lat': 17.3333,
#   'Lng': 42.6667,
#   'Max Temp': 85.14,
#   'Humidity': 58,
#   'Cloudiness': 10,
#   'Wind Speed': 5.97,
#   'Country': 'SA',
#   'Date': '2021-11-25 16:19:11'},
#  {'City': 'Sioux Lookout',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 6.87,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:19:11'},
#  {'City': 'Bella Union',
#   'Lat': -30.2752,
#   'Lng': -57.6007,
#   'Max Temp': 66.94,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.7,
#   'Country': 'UY',
#   'Date': '2021-11-25 16:19:12'},
#  {'City': 'Kamina',
#   'Lat': -8.7386,
#   'Lng': 24.9906,
#   'Max Temp': 70.03,
#   'Humidity': 82,
#   'Cloudiness': 76,
#   'Wind Speed': 4.03,
#   'Country': 'CD',
#   'Date': '2021-11-25 16:19:12'},
#  {'City': 'Amli',
#   'Lat': 20.2833,
#   'Lng': 73.0167,
#   'Max Temp': 76.87,
#   'Humidity': 47,
#   'Cloudiness': 36,
#   'Wind Speed': 5.23,
#   'Country': 'IN',
#   'Date': '2021-11-25 16:19:12'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 0.88,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:19:13'},
#  {'City': 'Foz',
#   'Lat': 43.5692,
#   'Lng': -7.2544,
#   'Max Temp': 52.93,
#   'Humidity': 88,
#   'Cloudiness': 97,
#   'Wind Speed': 11.54,
#   'Country': 'ES',
#   'Date': '2021-11-25 16:15:44'},
#  {'City': 'Sayyan',
#   'Lat': 15.1718,
#   'Lng': 44.3244,
#   'Max Temp': 57.83,
#   'Humidity': 32,
#   'Cloudiness': 56,
#   'Wind Speed': 7.58,
#   'Country': 'YE',
#   'Date': '2021-11-25 16:19:13'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 79.09,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'MU',
#   'Date': '2021-11-25 16:19:13'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -4.43,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 6.08,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:19:14'},
#  {'City': 'Fabiansebestyen',
#   'Lat': 46.6833,
#   'Lng': 20.4667,
#   'Max Temp': 47.03,
#   'Humidity': 67,
#   'Cloudiness': 8,
#   'Wind Speed': 9.44,
#   'Country': 'HU',
#   'Date': '2021-11-25 16:19:14'},
#  {'City': 'Kolhapur',
#   'Lat': 16.7,
#   'Lng': 74.2167,
#   'Max Temp': 73.44,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 3.62,
#   'Country': 'IN',
#   'Date': '2021-11-25 16:19:14'},
#  {'City': 'Bria',
#   'Lat': 6.5423,
#   'Lng': 21.9863,
#   'Max Temp': 81.45,
#   'Humidity': 35,
#   'Cloudiness': 49,
#   'Wind Speed': 2.64,
#   'Country': 'CF',
#   'Date': '2021-11-25 16:19:15'},
#  {'City': 'Namtsy',
#   'Lat': 62.7161,
#   'Lng': 129.6658,
#   'Max Temp': -16.49,
#   'Humidity': 99,
#   'Cloudiness': 85,
#   'Wind Speed': 1.01,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:19:15'},
#  {'City': 'Vila',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 47.32,
#   'Humidity': 74,
#   'Cloudiness': 70,
#   'Wind Speed': 7.43,
#   'Country': 'PT',
#   'Date': '2021-11-25 16:19:15'},
#  {'City': 'Vanavara',
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp': 7.27,
#   'Humidity': 99,
#   'Cloudiness': 96,
#   'Wind Speed': 2.66,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:19:16'},
#  {'City': 'Lagunas',
#   'Lat': -5.2269,
#   'Lng': -75.6753,
#   'Max Temp': 77.63,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.86,
#   'Country': 'PE',
#   'Date': '2021-11-25 16:19:16'},
#  {'City': 'Sagua La Grande',
#   'Lat': 22.8067,
#   'Lng': -80.0756,
#   'Max Temp': 79.79,
#   'Humidity': 62,
#   'Cloudiness': 96,
#   'Wind Speed': 10.27,
#   'Country': 'CU',
#   'Date': '2021-11-25 16:19:16'},
#  {'City': 'Brownsville',
#   'Lat': 25.9018,
#   'Lng': -97.4975,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-11-25 16:19:16'},
#  {'City': 'Capoterra',
#   'Lat': 39.1763,
#   'Lng': 8.9718,
#   'Max Temp': 56.57,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'IT',
#   'Date': '2021-11-25 16:19:17'},
#  {'City': 'Sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 30.06,
#   'Humidity': 63,
#   'Cloudiness': 95,
#   'Wind Speed': 9.33,
#   'Country': 'NO',
#   'Date': '2021-11-25 16:19:17'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 78.82,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 15.41,
#   'Country': 'PF',
#   'Date': '2021-11-25 16:19:17'},
#  {'City': 'Bonavista',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 48.2,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 23.17,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:19:18'},
#  {'City': 'Seymchan',
#   'Lat': 62.8833,
#   'Lng': 152.4333,
#   'Max Temp': -34.33,
#   'Humidity': 100,
#   'Cloudiness': 94,
#   'Wind Speed': 0.34,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:19:18'},
#  {'City': 'Verkhoyansk',
#   'Lat': 67.5447,
#   'Lng': 133.385,
#   'Max Temp': -35.03,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.36,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:19:19'},
#  {'City': 'Liaocheng',
#   'Lat': 36.4439,
#   'Lng': 115.9647,
#   'Max Temp': 45.28,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 1.68,
#   'Country': 'CN',
#   'Date': '2021-11-25 16:19:19'},
#  {'City': 'Kichera',
#   'Lat': 55.9375,
#   'Lng': 110.0997,
#   'Max Temp': 14.83,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.34,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:19:19'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 76.01,
#   'Humidity': 22,
#   'Cloudiness': 15,
#   'Wind Speed': 22.73,
#   'Country': 'AR',
#   'Date': '2021-11-25 16:19:19'},
#  {'City': 'Canutama',
#   'Lat': -6.5339,
#   'Lng': -64.3831,
#   'Max Temp': 84.25,
#   'Humidity': 78,
#   'Cloudiness': 93,
#   'Wind Speed': 1.16,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:19:20'},
#  {'City': 'Skjervoy',
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp': 15.8,
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 12.15,
#   'Country': 'NO',
#   'Date': '2021-11-25 16:19:20'},
#  {'City': 'Yantal',
#   'Lat': 56.8471,
#   'Lng': 105.2542,
#   'Max Temp': 17.53,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.41,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:19:20'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -21.26,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:19:21'},
#  {'City': 'Kiama',
#   'Lat': -34.6833,
#   'Lng': 150.8667,
#   'Max Temp': 64,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:19:21'},
#  {'City': 'Tuban',
#   'Lat': -6.8976,
#   'Lng': 112.0649,
#   'Max Temp': 77.72,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 10.83,
#   'Country': 'ID',
#   'Date': '2021-11-25 16:19:21'},
#  {'City': 'Urubicha',
#   'Lat': -15.3833,
#   'Lng': -62.95,
#   'Max Temp': 82.44,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 5.28,
#   'Country': 'BO',
#   'Date': '2021-11-25 16:19:22'},
#  {'City': 'Marienburg',
#   'Lat': 54.0359,
#   'Lng': 19.0266,
#   'Max Temp': 40.12,
#   'Humidity': 68,
#   'Cloudiness': 68,
#   'Wind Speed': 10.69,
#   'Country': 'PL',
#   'Date': '2021-11-25 16:19:22'},
#  {'City': 'Barao De Melgaco',
#   'Lat': -16.1944,
#   'Lng': -55.9675,
#   'Max Temp': 88.32,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.95,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:20:23'},
#  {'City': 'Baculin',
#   'Lat': 7.4525,
#   'Lng': 126.5842,
#   'Max Temp': 78.42,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 4.34,
#   'Country': 'PH',
#   'Date': '2021-11-25 16:20:23'},
#  {'City': 'Benjamin Aceval',
#   'Lat': -24.9667,
#   'Lng': -57.5667,
#   'Max Temp': 96.94,
#   'Humidity': 32,
#   'Cloudiness': 78,
#   'Wind Speed': 11.83,
#   'Country': 'PY',
#   'Date': '2021-11-25 16:20:23'},
#  {'City': 'Vestmanna',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 38.32,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 17.27,
#   'Country': 'FO',
#   'Date': '2021-11-25 16:20:24'},
#  {'City': 'Vanimo',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 78.73,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 2.08,
#   'Country': 'PG',
#   'Date': '2021-11-25 16:20:24'},
#  {'City': 'Leua',
#   'Lat': 48.2156,
#   'Lng': 18.6071,
#   'Max Temp': 40.5,
#   'Humidity': 74,
#   'Cloudiness': 46,
#   'Wind Speed': 11.54,
#   'Country': 'SK',
#   'Date': '2021-11-25 16:20:24'},
#  {'City': 'Ardesen',
#   'Lat': 41.1911,
#   'Lng': 40.9875,
#   'Max Temp': 48.16,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Country': 'TR',
#   'Date': '2021-11-25 16:20:25'},
#  {'City': 'Lokosovo',
#   'Lat': 61.1333,
#   'Lng': 74.8167,
#   'Max Temp': 0.68,
#   'Humidity': 99,
#   'Cloudiness': 96,
#   'Wind Speed': 7.67,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:20:25'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 67.39,
#   'Humidity': 61,
#   'Cloudiness': 5,
#   'Wind Speed': 13.76,
#   'Country': 'CL',
#   'Date': '2021-11-25 16:20:25'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 78.87,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 11.21,
#   'Country': 'UY',
#   'Date': '2021-11-25 16:20:26'},
#  {'City': 'Sompeta',
#   'Lat': 18.9333,
#   'Lng': 84.6,
#   'Max Temp': 76.44,
#   'Humidity': 82,
#   'Cloudiness': 65,
#   'Wind Speed': 3.13,
#   'Country': 'IN',
#   'Date': '2021-11-25 16:20:26'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 34.39,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:20:27'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 34.3,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 5.53,
#   'Country': 'GL',
#   'Date': '2021-11-25 16:20:27'},
#  {'City': 'Meulaboh',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 78.28,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.65,
#   'Country': 'ID',
#   'Date': '2021-11-25 16:20:27'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -17.43,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.46,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:20:28'},
#  {'City': 'Quimper',
#   'Lat': 48,
#   'Lng': -4.1,
#   'Max Temp': 47.08,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'FR',
#   'Date': '2021-11-25 16:20:28'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 60.89,
#   'Humidity': 82,
#   'Cloudiness': 92,
#   'Wind Speed': 23.87,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:20:28'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 4.78,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.29,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:20:29'},
#  {'City': 'Imues',
#   'Lat': 1.0607,
#   'Lng': -77.5004,
#   'Max Temp': 61.02,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Country': 'CO',
#   'Date': '2021-11-25 16:20:29'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 52.05,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-11-25 16:20:29'},
#  {'City': 'Kimbe',
#   'Lat': -5.5502,
#   'Lng': 150.1429,
#   'Max Temp': 74.98,
#   'Humidity': 95,
#   'Cloudiness': 62,
#   'Wind Speed': 4.16,
#   'Country': 'PG',
#   'Date': '2021-11-25 16:20:30'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 47.37,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-11-25 16:20:14'},
#  {'City': 'Porto Belo',
#   'Lat': -27.1578,
#   'Lng': -48.5531,
#   'Max Temp': 82.09,
#   'Humidity': 72,
#   'Cloudiness': 24,
#   'Wind Speed': 12.48,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:20:30'},
#  {'City': 'Eureka',
#   'Lat': 40.8021,
#   'Lng': -124.1637,
#   'Max Temp': 44.64,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Country': 'US',
#   'Date': '2021-11-25 16:20:31'},
#  {'City': 'Chegdomyn',
#   'Lat': 51.1167,
# ...
#   'Country': 'NZ',
#   'Date': '2021-11-25 16:26:45'},
#  {'City': 'Chanika',
#   'Lat': -5.4167,
#   'Lng': 38.0167,
#   'Max Temp': 77.04,
#   'Humidity': 68,
#   'Cloudiness': 93,
#   'Wind Speed': 11.5,
#   'Country': 'TZ',
#   'Date': '2021-11-25 16:26:45'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 55.22,
#   'Humidity': 95,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-11-25 16:24:27'},
#  {'City': 'Patrocinio',
#   'Lat': -18.9439,
#   'Lng': -46.9925,
#   'Max Temp': 86.95,
#   'Humidity': 39,
#   'Cloudiness': 97,
#   'Wind Speed': 6.67,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:26:46'},
#  {'City': 'Ginda',
#   'Lat': 30.6945,
#   'Lng': 78.4932,
#   'Max Temp': 46.44,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 5.91,
#   'Country': 'IN',
#   'Date': '2021-11-25 16:26:46'},
#  {'City': 'Oranjemund',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 66.6,
#   'Humidity': 74,
#   'Cloudiness': 44,
#   'Wind Speed': 11.61,
#   'Country': 'NA',
#   'Date': '2021-11-25 16:26:46'},
#  {'City': 'Ust-Nera',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': -29.06,
#   'Humidity': 98,
#   'Cloudiness': 75,
#   'Wind Speed': 1.66,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:26:47'},
#  {'City': 'Rethimnon',
#   'Lat': 35.3647,
#   'Lng': 24.4714,
#   'Max Temp': 60.85,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 7.31,
#   'Country': 'GR',
#   'Date': '2021-11-25 16:24:31'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 4.84,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2021-11-25 16:26:47'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 64.98,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 0.98,
#   'Country': 'MX',
#   'Date': '2021-11-25 16:26:47'},
#  {'City': 'Magadan',
#   'Lat': 59.5667,
#   'Lng': 150.8,
#   'Max Temp': 2.75,
#   'Humidity': 77,
#   'Cloudiness': 7,
#   'Wind Speed': 14.43,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:26:48'},
#  {'City': 'Darnah',
#   'Lat': 32.767,
#   'Lng': 22.6367,
#   'Max Temp': 68.54,
#   'Humidity': 63,
#   'Cloudiness': 79,
#   'Wind Speed': 13.27,
#   'Country': 'LY',
#   'Date': '2021-11-25 16:26:48'},
#  {'City': 'Riyadh',
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 73.54,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 8.61,
#   'Country': 'SA',
#   'Date': '2021-11-25 16:26:48'},
#  {'City': 'Matara',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 76.08,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 5.93,
#   'Country': 'LK',
#   'Date': '2021-11-25 16:26:49'},
#  {'City': 'Kramat',
#   'Lat': -8.1311,
#   'Lng': 113.4499,
#   'Max Temp': 76.26,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 0.38,
#   'Country': 'ID',
#   'Date': '2021-11-25 16:26:49'},
#  {'City': 'Cabedelo',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp': 90.27,
#   'Humidity': 64,
#   'Cloudiness': 67,
#   'Wind Speed': 12.12,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:26:49'},
#  {'City': 'Palmas',
#   'Lat': -10.2128,
#   'Lng': -48.3603,
#   'Max Temp': 80.47,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:25:35'},
#  {'City': 'Mizur',
#   'Lat': 42.8531,
#   'Lng': 44.0531,
#   'Max Temp': 24.62,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 4.83,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:26:50'},
#  {'City': 'Damietta',
#   'Lat': 31.4165,
#   'Lng': 31.8133,
#   'Max Temp': 69.17,
#   'Humidity': 66,
#   'Cloudiness': 22,
#   'Wind Speed': 7.02,
#   'Country': 'EG',
#   'Date': '2021-11-25 16:26:50'},
#  {'City': 'Sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 80.47,
#   'Humidity': 74,
#   'Cloudiness': 68,
#   'Wind Speed': 18.28,
#   'Country': 'VU',
#   'Date': '2021-11-25 16:26:50'},
#  {'City': 'Jonava',
#   'Lat': 55.0833,
#   'Lng': 24.2833,
#   'Max Temp': 39.25,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 4,
#   'Country': 'LT',
#   'Date': '2021-11-25 16:26:51'},
#  {'City': 'Althofen',
#   'Lat': 46.8818,
#   'Lng': 14.4676,
#   'Max Temp': 33.06,
#   'Humidity': 73,
#   'Cloudiness': 99,
#   'Wind Speed': 1.01,
#   'Country': 'AT',
#   'Date': '2021-11-25 16:26:52'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 91.89,
#   'Humidity': 18,
#   'Cloudiness': 22,
#   'Wind Speed': 7.27,
#   'Country': 'ML',
#   'Date': '2021-11-25 16:26:52'},
#  {'City': 'Sulangan',
#   'Lat': 11.1373,
#   'Lng': 123.7228,
#   'Max Temp': 83.39,
#   'Humidity': 77,
#   'Cloudiness': 44,
#   'Wind Speed': 9.66,
#   'Country': 'PH',
#   'Date': '2021-11-25 16:26:53'},
#  {'City': 'La Huacana',
#   'Lat': 18.9667,
#   'Lng': -101.8167,
#   'Max Temp': 80.44,
#   'Humidity': 51,
#   'Cloudiness': 6,
#   'Wind Speed': 2.57,
#   'Country': 'MX',
#   'Date': '2021-11-25 16:26:53'},
#  {'City': 'Bodden Town',
#   'Lat': 19.2833,
#   'Lng': -81.25,
#   'Max Temp': 82.4,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 13,
#   'Country': 'KY',
#   'Date': '2021-11-25 16:27:53'},
#  {'City': 'Mokhotlong',
#   'Lat': -29.2894,
#   'Lng': 29.0675,
#   'Max Temp': 49.42,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 8.66,
#   'Country': 'LS',
#   'Date': '2021-11-25 16:27:54'},
#  {'City': 'Verkhnyaya Khava',
#   'Lat': 51.8404,
#   'Lng': 39.9413,
#   'Max Temp': 35.67,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 10.09,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:27:54'},
#  {'City': 'Golden',
#   'Lat': 39.7555,
#   'Lng': -105.2211,
#   'Max Temp': 45.03,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-11-25 16:25:17'},
#  {'City': 'Teguldet',
#   'Lat': 57.3064,
#   'Lng': 88.1667,
#   'Max Temp': 17.13,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:27:54'},
#  {'City': 'Chiredzi',
#   'Lat': -21.05,
#   'Lng': 31.6667,
#   'Max Temp': 78.4,
#   'Humidity': 45,
#   'Cloudiness': 91,
#   'Wind Speed': 9.51,
#   'Country': 'ZW',
#   'Date': '2021-11-25 16:27:55'},
#  {'City': 'Tianjin',
#   'Lat': 39.1422,
#   'Lng': 117.1767,
#   'Max Temp': 33.75,
#   'Humidity': 86,
#   'Cloudiness': 2,
#   'Wind Speed': 4.47,
#   'Country': 'CN',
#   'Date': '2021-11-25 16:27:40'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 68.05,
#   'Humidity': 63,
#   'Cloudiness': 27,
#   'Wind Speed': 12.28,
#   'Country': 'MG',
#   'Date': '2021-11-25 16:27:55'},
#  {'City': 'Doha',
#   'Lat': 25.2867,
#   'Lng': 51.5333,
#   'Max Temp': 76.98,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'QA',
#   'Date': '2021-11-25 16:27:55'},
#  {'City': 'Feira De Santana',
#   'Lat': -12.2667,
#   'Lng': -38.9667,
#   'Max Temp': 80.8,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 10.11,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:27:56'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 74.71,
#   'Humidity': 64,
#   'Cloudiness': 11,
#   'Wind Speed': 8.5,
#   'Country': 'MR',
#   'Date': '2021-11-25 16:27:56'},
#  {'City': 'Puerto Narino',
#   'Lat': -3.7703,
#   'Lng': -70.3831,
#   'Max Temp': 86.54,
#   'Humidity': 64,
#   'Cloudiness': 93,
#   'Wind Speed': 3.02,
#   'Country': 'CO',
#   'Date': '2021-11-25 16:27:56'},
#  {'City': 'Merritt Island',
#   'Lat': 28.5392,
#   'Lng': -80.672,
#   'Max Temp': 77.09,
#   'Humidity': 53,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-11-25 16:27:57'},
#  {'City': 'Kralendijk',
#   'Lat': 12.15,
#   'Lng': -68.2667,
#   'Max Temp': 82.38,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'BQ',
#   'Date': '2021-11-25 16:27:57'},
#  {'City': 'Green River',
#   'Lat': 41.5286,
#   'Lng': -109.4662,
#   'Max Temp': 28.18,
#   'Humidity': 37,
#   'Cloudiness': 7,
#   'Wind Speed': 9.84,
#   'Country': 'US',
#   'Date': '2021-11-25 16:27:57'},
#  {'City': 'Luau',
#   'Lat': -10.7073,
#   'Lng': 22.2247,
#   'Max Temp': 70.5,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 0.54,
#   'Country': 'AO',
#   'Date': '2021-11-25 16:27:58'},
#  {'City': 'Camopi',
#   'Lat': 3.1655,
#   'Lng': -52.3158,
#   'Max Temp': 93.11,
#   'Humidity': 42,
#   'Cloudiness': 57,
#   'Wind Speed': 4.21,
#   'Country': 'GF',
#   'Date': '2021-11-25 16:27:58'},
#  {'City': 'Sterling',
#   'Lat': 39.0062,
#   'Lng': -77.4286,
#   'Max Temp': 54.77,
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-11-25 16:25:17'},
#  {'City': 'Arlit',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 91.74,
#   'Humidity': 11,
#   'Cloudiness': 1,
#   'Wind Speed': 6.55,
#   'Country': 'NE',
#   'Date': '2021-11-25 16:27:59'},
#  {'City': 'Sitrah',
#   'Lat': 26.1547,
#   'Lng': 50.6206,
#   'Max Temp': 75.36,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Country': 'BH',
#   'Date': '2021-11-25 16:27:59'},
#  {'City': 'Sheboygan',
#   'Lat': 43.7333,
#   'Lng': -87.9334,
#   'Max Temp': 37.51,
#   'Humidity': 90,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-11-25 16:28:00'},
#  {'City': 'Gizo',
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp': 82.18,
#   'Humidity': 74,
#   'Cloudiness': 44,
#   'Wind Speed': 2.73,
#   'Country': 'SB',
#   'Date': '2021-11-25 16:28:00'},
#  {'City': 'Alihe',
#   'Lat': 50.5667,
#   'Lng': 123.7167,
#   'Max Temp': 7.92,
#   'Humidity': 96,
#   'Cloudiness': 16,
#   'Wind Speed': 3.15,
#   'Country': 'CN',
#   'Date': '2021-11-25 16:28:00'},
#  {'City': 'Cauquenes',
#   'Lat': -35.9671,
#   'Lng': -72.3225,
#   'Max Temp': 81.41,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 5.55,
#   'Country': 'CL',
#   'Date': '2021-11-25 16:28:01'},
#  {'City': 'Chandbali',
#   'Lat': 20.7833,
#   'Lng': 86.7667,
#   'Max Temp': 73.51,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 6.08,
#   'Country': 'IN',
#   'Date': '2021-11-25 16:28:01'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 90.5,
#   'Humidity': 55,
#   'Cloudiness': 61,
#   'Wind Speed': 14.29,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:28:01'},
#  {'City': 'Okato',
#   'Lat': -39.2,
#   'Lng': 173.8833,
#   'Max Temp': 53.69,
#   'Humidity': 86,
#   'Cloudiness': 9,
#   'Wind Speed': 6.08,
#   'Country': 'NZ',
#   'Date': '2021-11-25 16:28:02'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 78.22,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'MX',
#   'Date': '2021-11-25 16:28:02'},
#  {'City': 'Saint-Francois',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 40.48,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'FR',
#   'Date': '2021-11-25 16:28:02'},
#  {'City': 'Tlacotepec',
#   'Lat': 20.0667,
#   'Lng': -97.8667,
#   'Max Temp': 68.23,
#   'Humidity': 63,
#   'Cloudiness': 5,
#   'Wind Speed': 4.18,
#   'Country': 'MX',
#   'Date': '2021-11-25 16:28:03'},
#  {'City': 'Tracy',
#   'Lat': 37.7397,
#   'Lng': -121.4252,
#   'Max Temp': 55.2,
#   'Humidity': 56,
#   'Cloudiness': 5,
#   'Wind Speed': 0.78,
#   'Country': 'US',
#   'Date': '2021-11-25 16:24:25'},
#  {'City': 'Sandakan',
#   'Lat': 5.8402,
#   'Lng': 118.1179,
#   'Max Temp': 78.48,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MY',
#   'Date': '2021-11-25 16:28:03'},
#  {'City': 'Capaci',
#   'Lat': 38.1711,
#   'Lng': 13.2393,
#   'Max Temp': 61.93,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'IT',
#   'Date': '2021-11-25 16:28:03'},
#  {'City': 'Bontang',
#   'Lat': 0.1333,
#   'Lng': 117.5,
#   'Max Temp': 79.83,
#   'Humidity': 84,
#   'Cloudiness': 97,
#   'Wind Speed': 3.04,
#   'Country': 'ID',
#   'Date': '2021-11-25 16:28:04'},
#  {'City': 'Mattru',
#   'Lat': 7.6244,
#   'Lng': -11.8332,
#   'Max Temp': 93.02,
#   'Humidity': 37,
#   'Cloudiness': 14,
#   'Wind Speed': 2.46,
#   'Country': 'SL',
#   'Date': '2021-11-25 16:28:04'},
#  {'City': 'Beira',
#   'Lat': -19.8436,
#   'Lng': 34.8389,
#   'Max Temp': 78.89,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Country': 'MZ',
#   'Date': '2021-11-25 16:28:04'},
#  {'City': 'Buribay',
#   'Lat': 51.9617,
#   'Lng': 58.1592,
#   'Max Temp': 17.92,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 20.24,
#   'Country': 'RU',
#   'Date': '2021-11-25 16:28:05'},
#  {'City': 'San Clemente',
#   'Lat': 33.427,
#   'Lng': -117.612,
#   'Max Temp': 69.42,
#   'Humidity': 18,
#   'Cloudiness': 3,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-11-25 16:24:46'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 77.5,
#   'Humidity': 75,
#   'Cloudiness': 98,
#   'Wind Speed': 11.7,
#   'Country': 'PW',
#   'Date': '2021-11-25 16:28:05'},
#  {'City': 'Xalpatlahuac',
#   'Lat': 17.4667,
#   'Lng': -98.6167,
#   'Max Temp': 70.79,
#   'Humidity': 53,
#   'Cloudiness': 2,
#   'Wind Speed': 2.44,
#   'Country': 'MX',
#   'Date': '2021-11-25 16:28:05'},
#  {'City': 'Clarence Town',
#   'Lat': -32.5833,
#   'Lng': 151.7833,
#   'Max Temp': 71.82,
#   'Humidity': 96,
#   'Cloudiness': 92,
#   'Wind Speed': 1.43,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:28:06'},
#  {'City': 'Cravo Norte',
#   'Lat': 6.3017,
#   'Lng': -70.2041,
#   'Max Temp': 81.86,
#   'Humidity': 74,
#   'Cloudiness': 99,
#   'Wind Speed': 5.23,
#   'Country': 'CO',
#   'Date': '2021-11-25 16:28:06'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 80.55,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:26:16'},
#  {'City': 'Middelburg',
#   'Lat': -25.7751,
#   'Lng': 29.4648,
#   'Max Temp': 61.93,
#   'Humidity': 69,
#   'Cloudiness': 89,
#   'Wind Speed': 10.8,
#   'Country': 'ZA',
#   'Date': '2021-11-25 16:28:06'},
#  {'City': 'Jumla',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 38.23,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 3.62,
#   'Country': 'NP',
#   'Date': '2021-11-25 16:28:07'},
#  {'City': 'Alyangula',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 80.47,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.14,
#   'Country': 'AU',
#   'Date': '2021-11-25 16:28:07'},
#  {'City': 'Neuquen',
#   'Lat': -38.9516,
#   'Lng': -68.0591,
#   'Max Temp': 78.69,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'AR',
#   'Date': '2021-11-25 16:28:07'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 63.88,
#   'Humidity': 61,
#   'Cloudiness': 66,
#   'Wind Speed': 20.74,
#   'Country': 'ZA',
#   'Date': '2021-11-25 16:28:08'},
#  {'City': 'Conakry',
#   'Lat': 9.538,
#   'Lng': -13.6773,
#   'Max Temp': 89.67,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'GN',
#   'Date': '2021-11-25 16:23:26'},
#  {'City': 'Aripuana',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 87.19,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 2.55,
#   'Country': 'BR',
#   'Date': '2021-11-25 16:29:08'},
#  {'City': 'Kenai',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 18.03,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-11-25 16:26:31'},
#  {'City': 'Terme',
#   'Lat': 41.2092,
#   'Lng': 36.9739,
#   'Max Temp': 51.96,
#   'Humidity': 80,
#   'Cloudiness': 98,
#   'Wind Speed': 5.93,
#   'Country': 'TR',
#   'Date': '2021-11-25 16:29:09'},
#  {'City': 'San Rafael',
#   'Lat': -34.6177,
#   'Lng': -68.3301,
#   'Max Temp': 79.84,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 7.23,
#   'Country': 'AR',
#   'Date': '2021-11-25 16:29:09'},
#  {'City': 'Ushtobe',
#   'Lat': 45.2514,
#   'Lng': 77.9838,
#   'Max Temp': 50.65,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 7.05,
#   'Country': 'KZ',
#   'Date': '2021-11-25 16:29:09'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 81.72,
#   'Humidity': 70,
#   'Cloudiness': 47,
#   'Wind Speed': 14.65,
#   'Country': 'MV',
#   'Date': '2021-11-25 16:29:10'},
#  {'City': 'Hof',
#   'Lat': 50.3167,
#   'Lng': 11.9167,
#   'Max Temp': 33.46,
#   'Humidity': 90,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'DE',
#   'Date': '2021-11-25 16:29:10'},
#  {'City': 'Thanh Hoa',
#   'Lat': 19.8,
#   'Lng': 105.7667,
#   'Max Temp': 64.54,
#   'Humidity': 75,
#   'Cloudiness': 2,
#   'Wind Speed': 1.54,
#   'Country': 'VN',
#   'Date': '2021-11-25 16:29:10'},
#  {'City': 'Gaoyou',
#   'Lat': 32.7858,
#   'Lng': 119.4278,
#   'Max Temp': 51.44,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 0.89,
#   'Country': 'CN',
#   'Date': '2021-11-25 16:29:11'},
#  {'City': 'Buala',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 80.15,
#   'Humidity': 81,
#   'Cloudiness': 78,
#   'Wind Speed': 4.88,
#   'Country': 'SB',
#   'Date': '2021-11-25 16:29:11'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Port Alfred -33.5906   26.8910     65.32        64          93
# 1  Saint-Philippe -21.3585   55.7679     80.19        82          61
# 2         Rikitea -23.1203 -134.9692     75.49        77          13
# 3          Caxito  -8.5785   13.6643     83.05        71          78
# 4        Yuncheng  35.0231  110.9928     44.62        41           0
# 5           Lagoa  39.0500  -27.9833     61.66        73          93
# 6         Ushuaia -54.8000  -68.3000     49.62        61          86
# 7        Chumikan  54.7183  135.3150     14.99        91          92
# 8          Castro -24.7911  -50.0119     80.15        47          77
# 9         Fortuna  40.5982 -124.1573     40.12        87           1
#
#    Wind Speed Country                 Date
# 0       21.63      ZA  2021-11-25 16:14:13
# 1        4.92      RE  2021-11-25 16:14:14
# 2       13.20      PF  2021-11-25 16:14:14
# 3        6.85      AO  2021-11-25 16:14:15
# 4        2.28      CN  2021-11-25 16:14:15
# 5       30.94      PT  2021-11-25 16:14:15
# 6        2.48      AR  2021-11-25 16:10:11
# 7        6.38      RU  2021-11-25 16:14:16
# 8        8.46      BR  2021-11-25 16:14:16
# 9       10.36      US  2021-11-25 16:11:54

# %%
# reorder columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0     Port Alfred      ZA  2021-11-25 16:14:13 -33.5906   26.8910     65.32
# 1  Saint-Philippe      RE  2021-11-25 16:14:14 -21.3585   55.7679     80.19
# 2         Rikitea      PF  2021-11-25 16:14:14 -23.1203 -134.9692     75.49
# 3          Caxito      AO  2021-11-25 16:14:15  -8.5785   13.6643     83.05
# 4        Yuncheng      CN  2021-11-25 16:14:15  35.0231  110.9928     44.62
#
#    Humidity  Cloudiness  Wind Speed
# 0        64          93       21.63
# 1        82          61        4.92
# 2        77          13       13.20
# 3        71          78        6.85
# 4        41           0        2.28

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                    Busselton
# Country                        AU
# Date          2021-11-25 16:14:17
# Lat                        -33.65
# Lng                      115.3333
# Max Temp                    66.04
# Humidity                       79
# Cloudiness                     56
# Wind Speed                  11.56
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 557     True
# 558     True
# 559     True
# 560     True
# 561    False
# Name: Lat, Length: 562, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 4      Yuncheng      CN  2021-11-25 16:14:15  35.0231  110.9928     44.62
# 5         Lagoa      PT  2021-11-25 16:14:15  39.0500  -27.9833     61.66
# 7      Chumikan      RU  2021-11-25 16:14:16  54.7183  135.3150     14.99
# 9       Fortuna      US  2021-11-25 16:11:54  40.5982 -124.1573     40.12
# 10  Yerbogachen      RU  2021-11-25 16:14:16  61.2767  108.0108      9.84
#
#     Humidity  Cloudiness  Wind Speed
# 4         41           0        2.28
# 5         73          93       30.94
# 7         91          92        6.38
# 9         87           1       10.36
# 10        97          99        4.59

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 'Max Temp',(10,-20))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: -0.884

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp',(-55,95))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: 0.636

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,20))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: 0.407

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,15))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: 0.191

# %%
# skill drill: Refactor the code we have been using for linear regression lines and plots to create the x- and y-values for the percent cloudiness and latitudes on the Northern Hemisphere DataFrame.
#     Call the plot_linear_regression function with the correct arguments to create the linear regression line and plot for percent cloudiness in the Northern Hemisphere. It should look like the following plot.  

# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Cloudiness', '% Cloudiness',(10,50))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: 0.236

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: 0.159

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,25))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: 0.109

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,35))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: -0.361

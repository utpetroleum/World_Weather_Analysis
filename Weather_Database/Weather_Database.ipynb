# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the citipy module.
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# 5. Perform an API call with the OpenWeatherMap.
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time

# %%
# 6. Retrieve the following information from the API call:
#     Latitude and longitude
#     Maximum temperature
#     Percent humidity
#     Percent cloudiness
#     Wind speed
#     Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | soyo
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | kaitangata
# Processing Record 4 of Set 1 | meadow lake
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 1 | nanortalik
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | nome
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | arman
# Processing Record 17 of Set 1 | nchelenge
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | khor
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | ozernovskiy
# Processing Record 22 of Set 1 | scurtu mare
# Processing Record 23 of Set 1 | gornopravdinsk
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | ponto novo
# Processing Record 30 of Set 1 | abu kamal
# Processing Record 31 of Set 1 | maragogi
# Processing Record 32 of Set 1 | xacmaz
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | chistogorskiy
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 1 | constitucion
# Processing Record 39 of Set 1 | nuqui
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | flin flon
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | imeni poliny osipenko
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | saint-philippe
# Processing Record 46 of Set 1 | buala
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | severo-kurilsk
# Processing Record 50 of Set 1 | capim grosso
# Processing Record 1 of Set 2 | santa rosa
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | katsuura
# Processing Record 4 of Set 2 | mount gambier
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | tuatapere
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | okhotsk
# Processing Record 10 of Set 2 | fuerte olimpo
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | narsaq
# Processing Record 14 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | byron bay
# Processing Record 18 of Set 2 | andenes
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | igualada
# Processing Record 21 of Set 2 | monrovia
# Processing Record 22 of Set 2 | cazaje
# City not found. Skipping...
# Processing Record 23 of Set 2 | geraldton
# Processing Record 24 of Set 2 | westport
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | torbay
# Processing Record 27 of Set 2 | hillsborough
# Processing Record 28 of Set 2 | san patricio
# Processing Record 29 of Set 2 | chokurdakh
# Processing Record 30 of Set 2 | beziers
# Processing Record 31 of Set 2 | mezen
# Processing Record 32 of Set 2 | kruisfontein
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | guerrero negro
# Processing Record 37 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 2 | talnakh
# Processing Record 39 of Set 2 | beringovskiy
# Processing Record 40 of Set 2 | flinders
# Processing Record 41 of Set 2 | tiszasuly
# Processing Record 42 of Set 2 | san cristobal
# Processing Record 43 of Set 2 | bredasdorp
# Processing Record 44 of Set 2 | bowen
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | cherskiy
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | oktyabrskoye
# Processing Record 49 of Set 2 | chuy
# Processing Record 50 of Set 2 | portsmouth
# Processing Record 1 of Set 3 | saint george
# Processing Record 2 of Set 3 | sikeston
# Processing Record 3 of Set 3 | sakakah
# Processing Record 4 of Set 3 | humaita
# Processing Record 5 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 3 | parana
# Processing Record 7 of Set 3 | fortuna
# Processing Record 8 of Set 3 | dzilam gonzalez
# Processing Record 9 of Set 3 | knysna
# Processing Record 10 of Set 3 | angoche
# Processing Record 11 of Set 3 | faanui
# Processing Record 12 of Set 3 | rio claro
# Processing Record 13 of Set 3 | klaksvik
# Processing Record 14 of Set 3 | rio brilhante
# Processing Record 15 of Set 3 | los llanos de aridane
# Processing Record 16 of Set 3 | villarrica
# Processing Record 17 of Set 3 | necochea
# Processing Record 18 of Set 3 | nyurba
# Processing Record 19 of Set 3 | altay
# Processing Record 20 of Set 3 | tkvarcheli
# City not found. Skipping...
# Processing Record 21 of Set 3 | khandyga
# Processing Record 22 of Set 3 | leningradskiy
# Processing Record 23 of Set 3 | milicz
# Processing Record 24 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 3 | port hardy
# Processing Record 26 of Set 3 | emba
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | lebu
# Processing Record 29 of Set 3 | ballina
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | bandarbeyla
# Processing Record 32 of Set 3 | benghazi
# Processing Record 33 of Set 3 | santander jimenez
# Processing Record 34 of Set 3 | laranjeiras do sul
# Processing Record 35 of Set 3 | erenhot
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | olinda
# Processing Record 38 of Set 3 | kidal
# Processing Record 39 of Set 3 | dobrusevo
# Processing Record 40 of Set 3 | clyde river
# Processing Record 41 of Set 3 | pangnirtung
# Processing Record 42 of Set 3 | saldanha
# Processing Record 43 of Set 3 | codrington
# Processing Record 44 of Set 3 | sabratah
# Processing Record 45 of Set 3 | ayan
# Processing Record 46 of Set 3 | goderich
# Processing Record 47 of Set 3 | carutapera
# Processing Record 48 of Set 3 | skibbereen
# Processing Record 49 of Set 3 | tasiilaq
# Processing Record 50 of Set 3 | tapa
# Processing Record 1 of Set 4 | malakal
# Processing Record 2 of Set 4 | blonduos
# City not found. Skipping...
# Processing Record 3 of Set 4 | hambantota
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | forssa
# Processing Record 6 of Set 4 | marrakesh
# Processing Record 7 of Set 4 | abha
# Processing Record 8 of Set 4 | shellbrook
# Processing Record 9 of Set 4 | luderitz
# Processing Record 10 of Set 4 | mogadishu
# Processing Record 11 of Set 4 | tommot
# Processing Record 12 of Set 4 | independence
# Processing Record 13 of Set 4 | avarua
# Processing Record 14 of Set 4 | mar del plata
# Processing Record 15 of Set 4 | huarmey
# Processing Record 16 of Set 4 | maniitsoq
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | sola
# Processing Record 19 of Set 4 | provideniya
# Processing Record 20 of Set 4 | kharovsk
# Processing Record 21 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 22 of Set 4 | esna
# Processing Record 23 of Set 4 | kathmandu
# Processing Record 24 of Set 4 | aykhal
# Processing Record 25 of Set 4 | mount darwin
# Processing Record 26 of Set 4 | seminole
# Processing Record 27 of Set 4 | belmonte
# Processing Record 28 of Set 4 | port lincoln
# Processing Record 29 of Set 4 | gillette
# Processing Record 30 of Set 4 | belaya gora
# Processing Record 31 of Set 4 | bonoua
# Processing Record 32 of Set 4 | kirakira
# Processing Record 33 of Set 4 | husavik
# Processing Record 34 of Set 4 | qasigiannguit
# Processing Record 35 of Set 4 | balad
# Processing Record 36 of Set 4 | haines junction
# Processing Record 37 of Set 4 | puerto madryn
# Processing Record 38 of Set 4 | kaset sombun
# Processing Record 39 of Set 4 | ekibastuz
# Processing Record 40 of Set 4 | bukachacha
# Processing Record 41 of Set 4 | vestmannaeyjar
# Processing Record 42 of Set 4 | paz de ariporo
# City not found. Skipping...
# Processing Record 43 of Set 4 | charters towers
# Processing Record 44 of Set 4 | vung tau
# Processing Record 45 of Set 4 | manavalakurichi
# Processing Record 46 of Set 4 | kirensk
# Processing Record 47 of Set 4 | hienghene
# Processing Record 48 of Set 4 | bengkulu
# Processing Record 49 of Set 4 | karratha
# Processing Record 50 of Set 4 | brits
# Processing Record 1 of Set 5 | srednekolymsk
# Processing Record 2 of Set 5 | sergeyevka
# Processing Record 3 of Set 5 | ponta delgada
# Processing Record 4 of Set 5 | khatanga
# Processing Record 5 of Set 5 | cap malheureux
# Processing Record 6 of Set 5 | norsup
# Processing Record 7 of Set 5 | kaeo
# Processing Record 8 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 5 | athens
# Processing Record 10 of Set 5 | chulumani
# Processing Record 11 of Set 5 | port augusta
# Processing Record 12 of Set 5 | stornoway
# Processing Record 13 of Set 5 | touros
# Processing Record 14 of Set 5 | meulaboh
# Processing Record 15 of Set 5 | kasongo-lunda
# Processing Record 16 of Set 5 | balakhta
# Processing Record 17 of Set 5 | zalantun
# Processing Record 18 of Set 5 | salinopolis
# Processing Record 19 of Set 5 | chaa-khol
# City not found. Skipping...
# Processing Record 20 of Set 5 | colac
# Processing Record 21 of Set 5 | aklavik
# Processing Record 22 of Set 5 | joshimath
# Processing Record 23 of Set 5 | valdosta
# Processing Record 24 of Set 5 | hofn
# Processing Record 25 of Set 5 | portland
# Processing Record 26 of Set 5 | tadine
# Processing Record 27 of Set 5 | mahebourg
# Processing Record 28 of Set 5 | payo
# Processing Record 29 of Set 5 | high level
# Processing Record 30 of Set 5 | gat
# Processing Record 31 of Set 5 | matai
# Processing Record 32 of Set 5 | zyryanovsk
# Processing Record 33 of Set 5 | limon
# Processing Record 34 of Set 5 | port townsend
# Processing Record 35 of Set 5 | bone
# Processing Record 36 of Set 5 | shache
# Processing Record 37 of Set 5 | agulu
# Processing Record 38 of Set 5 | lorengau
# Processing Record 39 of Set 5 | vostok
# Processing Record 40 of Set 5 | wewak
# Processing Record 41 of Set 5 | broken hill
# Processing Record 42 of Set 5 | soe
# Processing Record 43 of Set 5 | bubaque
# Processing Record 44 of Set 5 | alofi
# Processing Record 45 of Set 5 | brilon
# Processing Record 46 of Set 5 | pacific grove
# Processing Record 47 of Set 5 | mongua
# Processing Record 48 of Set 5 | banda aceh
# Processing Record 49 of Set 5 | richards bay
# Processing Record 50 of Set 5 | salalah
# Processing Record 1 of Set 6 | sorong
# Processing Record 2 of Set 6 | turukhansk
# Processing Record 3 of Set 6 | padang
# Processing Record 4 of Set 6 | ilulissat
# Processing Record 5 of Set 6 | henties bay
# Processing Record 6 of Set 6 | klyuchi
# Processing Record 7 of Set 6 | mersin
# Processing Record 8 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 6 | nan
# Processing Record 10 of Set 6 | vao
# Processing Record 11 of Set 6 | brae
# Processing Record 12 of Set 6 | ahuimanu
# Processing Record 13 of Set 6 | bosaso
# Processing Record 14 of Set 6 | hami
# Processing Record 15 of Set 6 | grindavik
# Processing Record 16 of Set 6 | saint-georges
# Processing Record 17 of Set 6 | qaqortoq
# Processing Record 18 of Set 6 | warri
# Processing Record 19 of Set 6 | victoria
# Processing Record 20 of Set 6 | terrace bay
# Processing Record 21 of Set 6 | nizhniy tsasuchey
# Processing Record 22 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 6 | lewistown
# Processing Record 24 of Set 6 | petauke
# Processing Record 25 of Set 6 | port elizabeth
# Processing Record 26 of Set 6 | aleksandrovskiy zavod
# Processing Record 27 of Set 6 | pahuatlan
# City not found. Skipping...
# Processing Record 28 of Set 6 | maiduguri
# Processing Record 29 of Set 6 | palembang
# Processing Record 30 of Set 6 | nivala
# Processing Record 31 of Set 6 | belyy yar
# Processing Record 32 of Set 6 | bereda
# Processing Record 33 of Set 6 | santo antonio do ica
# Processing Record 34 of Set 6 | hasanabad
# Processing Record 35 of Set 6 | kununurra
# Processing Record 36 of Set 6 | mecca
# Processing Record 37 of Set 6 | conde
# Processing Record 38 of Set 6 | wanning
# Processing Record 39 of Set 6 | waingapu
# Processing Record 40 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 41 of Set 6 | kodiak
# Processing Record 42 of Set 6 | ca mau
# Processing Record 43 of Set 6 | shakhtinsk
# Processing Record 44 of Set 6 | leshukonskoye
# Processing Record 45 of Set 6 | sao filipe
# Processing Record 46 of Set 6 | sur
# Processing Record 47 of Set 6 | pontianak
# Processing Record 48 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 6 | bogashevo
# Processing Record 50 of Set 6 | cuenca
# Processing Record 1 of Set 7 | praia da vitoria
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | half moon bay
# Processing Record 4 of Set 7 | chudovo
# Processing Record 5 of Set 7 | camacha
# Processing Record 6 of Set 7 | lasa
# Processing Record 7 of Set 7 | tuktoyaktuk
# Processing Record 8 of Set 7 | hammerfest
# Processing Record 9 of Set 7 | tottori
# Processing Record 10 of Set 7 | safaga
# Processing Record 11 of Set 7 | lavrentiya
# Processing Record 12 of Set 7 | atar
# Processing Record 13 of Set 7 | road town
# Processing Record 14 of Set 7 | rapar
# Processing Record 15 of Set 7 | vardo
# Processing Record 16 of Set 7 | pandan
# Processing Record 17 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 7 | faya
# Processing Record 19 of Set 7 | cayenne
# Processing Record 20 of Set 7 | oranjemund
# Processing Record 21 of Set 7 | myitkyina
# Processing Record 22 of Set 7 | ayakudi
# Processing Record 23 of Set 7 | new norfolk
# Processing Record 24 of Set 7 | talcahuano
# Processing Record 25 of Set 7 | merauke
# Processing Record 26 of Set 7 | yalvac
# Processing Record 27 of Set 7 | yaan
# Processing Record 28 of Set 7 | sakaraha
# Processing Record 29 of Set 7 | manyana
# Processing Record 30 of Set 7 | tamiahua
# Processing Record 31 of Set 7 | teeli
# Processing Record 32 of Set 7 | kuala krai
# City not found. Skipping...
# Processing Record 33 of Set 7 | coahuayana
# Processing Record 34 of Set 7 | yelyzavethradka
# Processing Record 35 of Set 7 | twentynine palms
# Processing Record 36 of Set 7 | ancud
# Processing Record 37 of Set 7 | mlonggo
# Processing Record 38 of Set 7 | lompoc
# Processing Record 39 of Set 7 | fairfield
# Processing Record 40 of Set 7 | port-gentil
# Processing Record 41 of Set 7 | hay river
# Processing Record 42 of Set 7 | nizhniy chir
# Processing Record 43 of Set 7 | berdigestyakh
# Processing Record 44 of Set 7 | manzhouli
# Processing Record 45 of Set 7 | kimbe
# Processing Record 46 of Set 7 | lagoa
# Processing Record 47 of Set 7 | griffith
# Processing Record 48 of Set 7 | jaragua
# Processing Record 49 of Set 7 | san carlos de bariloche
# Processing Record 50 of Set 7 | solnechnyy
# Processing Record 1 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 8 | moindou
# Processing Record 3 of Set 8 | vaitape
# Processing Record 4 of Set 8 | songkhla
# Processing Record 5 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 8 | dunedin
# Processing Record 7 of Set 8 | bhimunipatnam
# Processing Record 8 of Set 8 | hokitika
# Processing Record 9 of Set 8 | makakilo city
# Processing Record 10 of Set 8 | erzin
# Processing Record 11 of Set 8 | samarai
# Processing Record 12 of Set 8 | teya
# Processing Record 13 of Set 8 | yulara
# Processing Record 14 of Set 8 | naze
# Processing Record 15 of Set 8 | ariano irpino
# Processing Record 16 of Set 8 | agadez
# Processing Record 17 of Set 8 | orshanka
# Processing Record 18 of Set 8 | yuzhno-kurilsk
# Processing Record 19 of Set 8 | vodnyy
# Processing Record 20 of Set 8 | barao de melgaco
# Processing Record 21 of Set 8 | palmer
# Processing Record 22 of Set 8 | plettenberg bay
# Processing Record 23 of Set 8 | morogoro
# Processing Record 24 of Set 8 | mareeba
# Processing Record 25 of Set 8 | itarema
# Processing Record 26 of Set 8 | isangel
# Processing Record 27 of Set 8 | black river
# Processing Record 28 of Set 8 | east london
# Processing Record 29 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 8 | arlit
# Processing Record 31 of Set 8 | bathsheba
# Processing Record 32 of Set 8 | seydi
# Processing Record 33 of Set 8 | riyadh
# Processing Record 34 of Set 8 | tibiri
# Processing Record 35 of Set 8 | rundu
# Processing Record 36 of Set 8 | forestville
# Processing Record 37 of Set 8 | oistins
# Processing Record 38 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 39 of Set 8 | katima mulilo
# Processing Record 40 of Set 8 | kayerkan
# Processing Record 41 of Set 8 | fairlie
# Processing Record 42 of Set 8 | douentza
# Processing Record 43 of Set 8 | gaoua
# Processing Record 44 of Set 8 | vila
# Processing Record 45 of Set 8 | pochutla
# Processing Record 46 of Set 8 | cidreira
# Processing Record 47 of Set 8 | batticaloa
# Processing Record 48 of Set 8 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 49 of Set 8 | oktyabrskiy
# Processing Record 50 of Set 8 | mount isa
# Processing Record 1 of Set 9 | teahupoo
# Processing Record 2 of Set 9 | mayo
# Processing Record 3 of Set 9 | college
# Processing Record 4 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 9 | havre-saint-pierre
# Processing Record 6 of Set 9 | dharchula
# Processing Record 7 of Set 9 | banjar
# Processing Record 8 of Set 9 | kyzyl-suu
# Processing Record 9 of Set 9 | fare
# Processing Record 10 of Set 9 | labuhan
# Processing Record 11 of Set 9 | pokaran
# Processing Record 12 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 13 of Set 9 | tutoia
# Processing Record 14 of Set 9 | bartica
# Processing Record 15 of Set 9 | eureka
# Processing Record 16 of Set 9 | noumea
# Processing Record 17 of Set 9 | avera
# Processing Record 18 of Set 9 | chau doc
# Processing Record 19 of Set 9 | macusani
# Processing Record 20 of Set 9 | ambulu
# Processing Record 21 of Set 9 | boshnyakovo
# Processing Record 22 of Set 9 | lianran
# Processing Record 23 of Set 9 | campos belos
# Processing Record 24 of Set 9 | nosy varika
# Processing Record 25 of Set 9 | dembi dolo
# Processing Record 26 of Set 9 | beloha
# Processing Record 27 of Set 9 | hailar
# Processing Record 28 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 9 | sibolga
# Processing Record 30 of Set 9 | balkanabat
# Processing Record 31 of Set 9 | alakurtti
# Processing Record 32 of Set 9 | kushiro
# Processing Record 33 of Set 9 | tukrah
# Processing Record 34 of Set 9 | thiene
# Processing Record 35 of Set 9 | saint-leu
# Processing Record 36 of Set 9 | inuvik
# Processing Record 37 of Set 9 | tavda
# Processing Record 38 of Set 9 | mehamn
# Processing Record 39 of Set 9 | glossa
# Processing Record 40 of Set 9 | bandar penggaram
# City not found. Skipping...
# Processing Record 41 of Set 9 | batemans bay
# Processing Record 42 of Set 9 | sitka
# Processing Record 43 of Set 9 | norman wells
# Processing Record 44 of Set 9 | kihei
# Processing Record 45 of Set 9 | christchurch
# Processing Record 46 of Set 9 | ibaiti
# Processing Record 47 of Set 9 | keflavik
# Processing Record 48 of Set 9 | pevek
# Processing Record 49 of Set 9 | afrikanda
# Processing Record 50 of Set 9 | the valley
# Processing Record 1 of Set 10 | sistranda
# Processing Record 2 of Set 10 | fort abbas
# Processing Record 3 of Set 10 | dauphin
# Processing Record 4 of Set 10 | conceicao da barra
# Processing Record 5 of Set 10 | ouallam
# Processing Record 6 of Set 10 | marawi
# Processing Record 7 of Set 10 | maunabo
# Processing Record 8 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 9 of Set 10 | mapastepec
# Processing Record 10 of Set 10 | jutai
# Processing Record 11 of Set 10 | egvekinot
# Processing Record 12 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 13 of Set 10 | udachnyy
# Processing Record 14 of Set 10 | wadi maliz
# Processing Record 15 of Set 10 | mhasla
# Processing Record 16 of Set 10 | evensk
# Processing Record 17 of Set 10 | taltal
# Processing Record 18 of Set 10 | esperance
# Processing Record 19 of Set 10 | sterling
# Processing Record 20 of Set 10 | pitangui
# Processing Record 21 of Set 10 | suleja
# Processing Record 22 of Set 10 | new waterford
# Processing Record 23 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 10 | mulchen
# Processing Record 25 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 26 of Set 10 | fengzhen
# Processing Record 27 of Set 10 | tomatlan
# Processing Record 28 of Set 10 | haines city
# Processing Record 29 of Set 10 | ust-tsilma
# Processing Record 30 of Set 10 | berezovka
# Processing Record 31 of Set 10 | chadiza
# Processing Record 32 of Set 10 | tombouctou
# Processing Record 33 of Set 10 | ucluelet
# Processing Record 34 of Set 10 | irpa irpa
# Processing Record 35 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 10 | caraballeda
# Processing Record 37 of Set 10 | igarka
# Processing Record 38 of Set 10 | eyl
# Processing Record 39 of Set 10 | valparaiso
# Processing Record 40 of Set 10 | nishihara
# Processing Record 41 of Set 10 | marzuq
# Processing Record 42 of Set 10 | linjiang
# Processing Record 43 of Set 10 | la sarre
# Processing Record 44 of Set 10 | mwinilunga
# Processing Record 45 of Set 10 | mackay
# Processing Record 46 of Set 10 | namatanai
# Processing Record 47 of Set 10 | chom bung
# City not found. Skipping...
# Processing Record 48 of Set 10 | olafsvik
# Processing Record 49 of Set 10 | tura
# Processing Record 50 of Set 10 | tshane
# Processing Record 1 of Set 11 | buta
# Processing Record 2 of Set 11 | coalinga
# Processing Record 3 of Set 11 | aripuana
# Processing Record 4 of Set 11 | harper
# Processing Record 5 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 11 | samfya
# Processing Record 7 of Set 11 | rio gallegos
# Processing Record 8 of Set 11 | kieta
# Processing Record 9 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 10 of Set 11 | hamilton
# Processing Record 11 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 11 | kushima
# Processing Record 13 of Set 11 | ambanja
# Processing Record 14 of Set 11 | bonthe
# Processing Record 15 of Set 11 | nikolayevsk-na-amure
# Processing Record 16 of Set 11 | biltine
# Processing Record 17 of Set 11 | santana do ipanema
# Processing Record 18 of Set 11 | otradnoye
# Processing Record 19 of Set 11 | joao camara
# Processing Record 20 of Set 11 | jinka
# Processing Record 21 of Set 11 | rocha
# Processing Record 22 of Set 11 | umm kaddadah
# Processing Record 23 of Set 11 | derzhavinsk
# Processing Record 24 of Set 11 | muisne
# Processing Record 25 of Set 11 | zhanaozen
# Processing Record 26 of Set 11 | mulege
# Processing Record 27 of Set 11 | lichinga
# Processing Record 28 of Set 11 | souillac
# Processing Record 29 of Set 11 | amalapuram
# Processing Record 30 of Set 11 | ankazoabo
# Processing Record 31 of Set 11 | sevsk
# Processing Record 32 of Set 11 | rockport
# Processing Record 33 of Set 11 | vila velha
# Processing Record 34 of Set 11 | itoman
# Processing Record 35 of Set 11 | grimshaw
# Processing Record 36 of Set 11 | klyuchevsk
# Processing Record 37 of Set 11 | kunming
# Processing Record 38 of Set 11 | churachandpur
# Processing Record 39 of Set 11 | banamba
# Processing Record 40 of Set 11 | mnogovershinnyy
# Processing Record 41 of Set 11 | dengzhou
# Processing Record 42 of Set 11 | adrar
# Processing Record 43 of Set 11 | sao joao da barra
# Processing Record 44 of Set 11 | imbituba
# Processing Record 45 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 11 | borovsk
# Processing Record 47 of Set 11 | namibe
# Processing Record 48 of Set 11 | balabac
# Processing Record 49 of Set 11 | nioro
# Processing Record 50 of Set 11 | vila franca do campo
# Processing Record 1 of Set 12 | mayumba
# Processing Record 2 of Set 12 | zhengjiatun
# Processing Record 3 of Set 12 | saint-denis
# Processing Record 4 of Set 12 | mungaa
# Processing Record 5 of Set 12 | sungairaya
# Processing Record 6 of Set 12 | nyrob
# Processing Record 7 of Set 12 | chumphon
# Processing Record 8 of Set 12 | kralendijk
# Processing Record 9 of Set 12 | rayevskiy
# Processing Record 10 of Set 12 | hualmay
# Processing Record 11 of Set 12 | kloulklubed
# Processing Record 12 of Set 12 | charyshskoye
# Processing Record 13 of Set 12 | rosignol
# Processing Record 14 of Set 12 | ambon
# Processing Record 15 of Set 12 | jardim
# Processing Record 16 of Set 12 | stephenville
# Processing Record 17 of Set 12 | puro
# Processing Record 18 of Set 12 | rey bouba
# Processing Record 19 of Set 12 | diplo
# Processing Record 20 of Set 12 | kansanshi
# Processing Record 21 of Set 12 | salgueiro
# Processing Record 22 of Set 12 | tateyama
# Processing Record 23 of Set 12 | carrara
# Processing Record 24 of Set 12 | port moresby
# Processing Record 25 of Set 12 | kisangani
# Processing Record 26 of Set 12 | quelimane
# Processing Record 27 of Set 12 | yilan
# Processing Record 28 of Set 12 | roebourne
# Processing Record 29 of Set 12 | nanakuli
# Processing Record 30 of Set 12 | viedma
# Processing Record 31 of Set 12 | rostovka
# Processing Record 32 of Set 12 | laguna
# Processing Record 33 of Set 12 | nusaybin
# Processing Record 34 of Set 12 | atambua
# Processing Record 35 of Set 12 | lewiston
# Processing Record 36 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 12 | vadso
# Processing Record 39 of Set 12 | baoro
# Processing Record 40 of Set 12 | katobu
# Processing Record 41 of Set 12 | krivosheino
# Processing Record 42 of Set 12 | warrnambool
# Processing Record 43 of Set 12 | sao jose do calcado
# Processing Record 44 of Set 12 | alyangula
# Processing Record 45 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 12 | ende
# Processing Record 47 of Set 12 | port blair
# Processing Record 48 of Set 12 | agadir
# Processing Record 49 of Set 12 | korla
# Processing Record 50 of Set 12 | khani
# Processing Record 1 of Set 13 | asau
# Processing Record 2 of Set 13 | ahipara
# Processing Record 3 of Set 13 | umba
# Processing Record 4 of Set 13 | pueblo nuevo
# Processing Record 5 of Set 13 | aden
# Processing Record 6 of Set 13 | halifax
# Processing Record 7 of Set 13 | semporna
# Processing Record 8 of Set 13 | coulihaut
# City not found. Skipping...
# Processing Record 9 of Set 13 | redlands
# Processing Record 10 of Set 13 | pontes e lacerda
# Processing Record 11 of Set 13 | caravelas
# Processing Record 12 of Set 13 | ciras
# City not found. Skipping...
# Processing Record 13 of Set 13 | broome
# Processing Record 14 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 15 of Set 13 | basco
# Processing Record 16 of Set 13 | barkhan
# Processing Record 17 of Set 13 | pirgos
# Processing Record 18 of Set 13 | yumen
# Processing Record 19 of Set 13 | dawson creek
# Processing Record 20 of Set 13 | panacan
# Processing Record 21 of Set 13 | acari
# Processing Record 22 of Set 13 | jonesboro
# Processing Record 23 of Set 13 | torrington
# Processing Record 24 of Set 13 | bambanglipuro
# Processing Record 25 of Set 13 | mochicahui
# Processing Record 26 of Set 13 | yar-sale
# Processing Record 27 of Set 13 | yelanskiy
# Processing Record 28 of Set 13 | luganville
# Processing Record 29 of Set 13 | sioux lookout
# Processing Record 30 of Set 13 | watertown
# Processing Record 31 of Set 13 | meadville
# Processing Record 32 of Set 13 | bambous virieux
# Processing Record 33 of Set 13 | upata
# Processing Record 34 of Set 13 | finnsnes
# Processing Record 35 of Set 13 | huambo
# Processing Record 36 of Set 13 | mahajanga
# Processing Record 37 of Set 13 | dingle
# Processing Record 38 of Set 13 | smithers
# Processing Record 39 of Set 13 | airai
# Processing Record 40 of Set 13 | saint anthony
# Processing Record 41 of Set 13 | saint-michel-des-saints
# Processing Record 42 of Set 13 | kahului
# Processing Record 43 of Set 13 | dakar
# Processing Record 44 of Set 13 | auki
# Processing Record 45 of Set 13 | japura
# Processing Record 46 of Set 13 | santa cruz de la palma
# Processing Record 47 of Set 13 | beitbridge
# Processing Record 48 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 13 | prudentopolis
# Processing Record 50 of Set 13 | elliot
# Processing Record 1 of Set 14 | yerkoy
# Processing Record 2 of Set 14 | veraval
# Processing Record 3 of Set 14 | nizhnyaya tavda
# Processing Record 4 of Set 14 | changji
# Processing Record 5 of Set 14 | olga
# Processing Record 6 of Set 14 | kualakapuas
# Processing Record 7 of Set 14 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 8 of Set 14 | vyartsilya
# Processing Record 9 of Set 14 | dordrecht
# Processing Record 10 of Set 14 | kalomo
# City not found. Skipping...
# Processing Record 11 of Set 14 | sainte-anne-des-monts
# Processing Record 12 of Set 14 | vitim
# Processing Record 13 of Set 14 | matara
# Processing Record 14 of Set 14 | sosua
# Processing Record 15 of Set 14 | ngunguru
# Processing Record 16 of Set 14 | okato
# Processing Record 17 of Set 14 | klimovsk
# Processing Record 18 of Set 14 | sambava
# Processing Record 19 of Set 14 | sinnamary
# Processing Record 20 of Set 14 | jinchang
# Processing Record 21 of Set 14 | kiunga
# Processing Record 22 of Set 14 | porto walter
# Processing Record 23 of Set 14 | arrecife
# Processing Record 24 of Set 14 | kangaatsiaq
# Processing Record 25 of Set 14 | manta
# Processing Record 26 of Set 14 | launceston
# Processing Record 27 of Set 14 | linshu
# City not found. Skipping...
# Processing Record 28 of Set 14 | turbat
# Processing Record 29 of Set 14 | marjamaa
# Processing Record 30 of Set 14 | bognor regis
# Processing Record 31 of Set 14 | vanavara
# Processing Record 32 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 14 | jalingo
# Processing Record 34 of Set 14 | deputatskiy
# Processing Record 35 of Set 14 | severnyy
# Processing Record 36 of Set 14 | hovd
# Processing Record 37 of Set 14 | san quintin
# Processing Record 38 of Set 14 | te anau
# Processing Record 39 of Set 14 | pisco
# Processing Record 40 of Set 14 | atlantic city
# Processing Record 41 of Set 14 | veinticinco de mayo
# Processing Record 42 of Set 14 | dwarka
# Processing Record 43 of Set 14 | dingli
# Processing Record 44 of Set 14 | ust-kut
# Processing Record 45 of Set 14 | katangli
# Processing Record 46 of Set 14 | pahrump
# Processing Record 47 of Set 14 | jalu
# Processing Record 48 of Set 14 | teknaf
# Processing Record 49 of Set 14 | cabra
# Processing Record 50 of Set 14 | minudasht
# Processing Record 1 of Set 15 | saurimo
# Processing Record 2 of Set 15 | mosquera
# Processing Record 3 of Set 15 | longhua
# Processing Record 4 of Set 15 | northam
# Processing Record 5 of Set 15 | kulu
# Processing Record 6 of Set 15 | samana
# Processing Record 7 of Set 15 | jumla
# Processing Record 8 of Set 15 | kjollefjord
# Processing Record 9 of Set 15 | yangjiang
# Processing Record 10 of Set 15 | horki
# Processing Record 11 of Set 15 | cupira
# Processing Record 12 of Set 15 | gayeri
# Processing Record 13 of Set 15 | guaranda
# Processing Record 14 of Set 15 | livingstone
# Processing Record 15 of Set 15 | papillion
# Processing Record 16 of Set 15 | nushki
# Processing Record 17 of Set 15 | aktau
# Processing Record 18 of Set 15 | jizan
# Processing Record 19 of Set 15 | ergani
# Processing Record 20 of Set 15 | caluquembe
# Processing Record 21 of Set 15 | heihe
# Processing Record 22 of Set 15 | banswada
# Processing Record 23 of Set 15 | margate
# Processing Record 24 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 25 of Set 15 | zverinogolovskoye
# Processing Record 26 of Set 15 | chiredzi
# Processing Record 27 of Set 15 | tual
# Processing Record 28 of Set 15 | santa cruz
# Processing Record 29 of Set 15 | chapais
# Processing Record 30 of Set 15 | roblin
# Processing Record 31 of Set 15 | saint-joseph
# Processing Record 32 of Set 15 | ilabaya
# Processing Record 33 of Set 15 | anadyr
# Processing Record 34 of Set 15 | manokwari
# Processing Record 35 of Set 15 | hervey bay
# Processing Record 36 of Set 15 | brownwood
# Processing Record 37 of Set 15 | lovozero
# Processing Record 38 of Set 15 | waconia
# Processing Record 39 of Set 15 | demba
# Processing Record 40 of Set 15 | manzanillo
# Processing Record 41 of Set 15 | zhicheng
# Processing Record 42 of Set 15 | loukhi
# Processing Record 43 of Set 15 | lagos
# Processing Record 44 of Set 15 | ostrovnoy
# Processing Record 45 of Set 15 | lebanon
# Processing Record 46 of Set 15 | san andres
# Processing Record 47 of Set 15 | ixtapa
# Processing Record 48 of Set 15 | joao pinheiro
# Processing Record 49 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 15 | cockburn town
# Processing Record 1 of Set 16 | bloemfontein
# Processing Record 2 of Set 16 | orotukan
# Processing Record 3 of Set 16 | prainha
# Processing Record 4 of Set 16 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 16 | bystryy istok
# Processing Record 6 of Set 16 | porto santo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to a new DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Soyo  -6.1349   12.3689     78.49        87         100       10.04
# 1   Kaitangata -46.2817  169.8464     51.22        57         100        6.60
# 2  Meadow Lake  34.8014 -106.5436     47.68        40          32        1.92
# 3    Busselton -33.6500  115.3333     80.15        40         100        5.46
# 4      Mataura -46.1927  168.8643     57.78        44         100        4.88
#
#   Country Current Description
# 0      AO     overcast clouds
# 1      NZ     overcast clouds
# 2      US    scattered clouds
# 3      AU     overcast clouds
# 4      NZ     overcast clouds

# %%
# reorder columns
new_column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Soyo      AO  -6.1349   12.3689     78.49        87         100
# 1   Kaitangata      NZ -46.2817  169.8464     51.22        57         100
# 2  Meadow Lake      US  34.8014 -106.5436     47.68        40          32
# 3    Busselton      AU -33.6500  115.3333     80.15        40         100
# 4      Mataura      NZ -46.1927  168.8643     57.78        44         100
#
#    Wind Speed Current Description
# 0       10.04     overcast clouds
# 1        6.60     overcast clouds
# 2        1.92    scattered clouds
# 3        5.46     overcast clouds
# 4        4.88     overcast clouds

# %%
# 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
